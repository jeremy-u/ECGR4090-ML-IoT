# %% [markdown]
# ## Basic Steps
#
# 0. Fix the paths so that they point to the directory where you have data downloaded.
# 1. Run a baseline training script to build a speech commands model.
# 2. Add in your custom word to the training and test/validation sets.
#    - Modify labels, shape of your output tensor in the model.
#    - Make sure that feature extractor for the model aligns with the feature extractor
#      used in the arduino code.
# 3. Re-train model. => TF Model using floating-point numbers, that recognizes Google word and custom word.
# 4. Quantize the model and convert to TFlite. => keyword_model.tflite file
# 5. Convert tflite to .c file, using xxd => model_data.cc
# 6. Replace contents of existing micro_features_model.cpp with output of xxd.
#
# All of the above steps are done in this notebook for the commands 'left', 'right'.
#
# 7. In micro_speech.ino, modify micro_op_resolver (around line 80) to add any necessary operations (DIFF_FROM_LECTURE)
# 8. In micro_features_model_settings.h, modify kSilenceIndex and kUnknownIndex, depending on
# where you have them in commands.
#   - Commands = ['left', 'right', '_silence', '_unknown'] => kSilenceIndex=2, kUnknownIndex=3
# 9. In micro_features_model_settings.cpp, modify kCategoryLabels to correspond to commands in this script.
# 10. In micro_features_micro_model_settings.h, set kFeatureSliceDurationMs, kFeatureSliceStrideMs to match what is passed to microfrontend as window_size, window_step, respectively. Set kFeatureSliceSize to num_channels and kFeatureSliceCount to the input_shape[0] (microfrontend will extract as many frames of spectra from 1s of audio as it can.)  Also set kMaxAudioSampleSize to be the next largest power of 2 greater than or equal to kFeatureSliceDurationMs*16000/1000 (1024 in this case)
# 11. Rebuild Arduino program, run it, recognize the two target words.
# 12. Experiment with model architecture, training parameters/methods, augmentation, more data-gathering, etc.
#
# *Note*:  As of 5/10/21, this model uses 21% of flash and 50% of RAM, so there is substantial space to improve the model, but the latency is about 40ms.

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow.keras import Input, layers
from tensorflow.keras import models
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.lite.experimental.microfrontend.python.ops import audio_microfrontend_op as frontend_op
print(tf.__version__)

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os
import pathlib

from IPython import display
# Out:
# 2.3.2

# %%
# Set seed for experiment reproducibility
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
i16min = -2**15
i16max = 2**15-1
fsamp = 16000
wave_length_ms = 1000
wave_length_samps = int(wave_length_ms*fsamp/1000)
window_size_ms=60
window_step_ms=40
num_channels = 30
use_microfrontend = True
dataset = 'mini-speech' #  'full-speech' # 'mini-speech' # 
silence_str = "_silence"  
unknown_str = "_unknown"
EPOCHS = 50

# %%
# !ls /home/jeremy/data/mini_speech_commands
# Out:
# down  go  left	no  README.md  right  stop  up	yes

# %% [markdown]
# Apply the frontend to an example signal.

# %%
if dataset == 'mini-speech':
  data_dir = pathlib.Path(os.path.join(os.getenv("HOME"), 'data/mini_speech_commands'))
  if not data_dir.exists():
    tf.keras.utils.get_file('mini_speech_commands.zip',
          origin="http://storage.googleapis.com/download.tensorflow.org/data/mini_speech_commands.zip",
          extract=True, cache_dir='.', cache_subdir='data')
  commands = np.array(tf.io.gfile.listdir(str(data_dir)))
  # commands = commands[commands != 'README.md']
  commands = ['left', 'right']
elif dataset == 'full-speech':
  # data_dir = '/dfs/org/Holleman-Coursework/data/speech_dataset'
  data_dir = '/home/jeremy/data/speech_commands_v0.02'
  commands = ['left', 'right']

# %%
label_list = commands.copy()
label_list.insert(0, silence_str)
label_list.insert(1, unknown_str)

# %%
print('label_list:', label_list)
# Out:
# label_list: ['_silence', '_unknown', 'left', 'right']

# %%
filenames = tf.io.gfile.glob(str(data_dir) + '/*/*.wav') 
# with the next commented-out line, you can choose only files for words in label_list
# filenames = tf.concat([tf.io.gfile.glob(str(data_dir) + '/' + cmd + '/*') for cmd in label_list], 0)
filenames = tf.random.shuffle(filenames)
num_samples = len(filenames)
print('Number of total examples:', num_samples)
# print('Number of examples per label:',
#       len(tf.io.gfile.listdir(str(data_dir/commands[0]))))
print('Example file tensor:', filenames[0])
# Out:
# Number of total examples: 8000
# Example file tensor: tf.Tensor(b'/home/jeremy/data/mini_speech_commands/down/6727b579_nohash_3.wav', shape=(), dtype=string)

# %%
filenames
# tf.strings.split(filenames[0], os.path.sep)[-2].numpy().decode('utf8')
# Out:
# <tf.Tensor: shape=(8000,), dtype=string, numpy=
# array([b'/home/jeremy/data/mini_speech_commands/down/6727b579_nohash_3.wav',
#        b'/home/jeremy/data/mini_speech_commands/right/e649aa92_nohash_0.wav',
#        b'/home/jeremy/data/mini_speech_commands/go/3f2b358d_nohash_3.wav',
#        ...,
#        b'/home/jeremy/data/mini_speech_commands/down/10ace7eb_nohash_0.wav',
#        b'/home/jeremy/data/mini_speech_commands/left/5aac2efa_nohash_0.wav',
#        b'/home/jeremy/data/mini_speech_commands/down/333784b7_nohash_2.wav'],
#       dtype=object)>

# %%
# Not really necessary, but just look at a few of the files to make sure that 
# they're the correct files, shuffled, etc.
for i in range(10):
    print(filenames[i].numpy().decode('utf8'))
# Out:
# /home/jeremy/data/mini_speech_commands/down/6727b579_nohash_3.wav
# /home/jeremy/data/mini_speech_commands/right/e649aa92_nohash_0.wav
# /home/jeremy/data/mini_speech_commands/go/3f2b358d_nohash_3.wav
# /home/jeremy/data/mini_speech_commands/no/a24cf51c_nohash_1.wav
# /home/jeremy/data/mini_speech_commands/stop/46a153d8_nohash_2.wav
# /home/jeremy/data/mini_speech_commands/go/df1d5024_nohash_3.wav
# /home/jeremy/data/mini_speech_commands/go/8056e897_nohash_1.wav
# /home/jeremy/data/mini_speech_commands/down/3847619e_nohash_0.wav
# /home/jeremy/data/mini_speech_commands/stop/0135f3f2_nohash_1.wav
# /home/jeremy/data/mini_speech_commands/stop/be7a5b2d_nohash_4.wav

# %%
if dataset == 'mini-speech':
  print('Using mini-speech')
  num_train_files = int(0.8*num_samples) 
  num_val_files = int(0.1*num_samples) 
  num_test_files = num_samples - num_train_files - num_val_files
  train_files = filenames[:num_train_files]
  val_files = filenames[num_train_files: num_train_files + num_val_files]
  test_files = filenames[-num_test_files:]
elif dataset == 'full-speech':  
  # the full speech-commands set lists which files are to be used
  # as test and validation data; train with everything else
  fname_val_files = os.path.join(data_dir, 'validation_list.txt')    
  with open(fname_val_files) as fpi_val:
    val_files = fpi_val.read().splitlines()
  # validation_list.txt only lists partial paths
  val_files = [os.path.join(data_dir, fn) for fn in val_files]
  fname_test_files = os.path.join(data_dir, 'testing_list.txt')

  with open(fname_test_files) as fpi_tst:
    test_files = fpi_tst.read().splitlines()
  # testing_list.txt only lists partial paths
  test_files = [os.path.join(data_dir, fn).rstrip() for fn in test_files]    

  # convert the TF tensor filenames into an array of strings so we can use basic python constructs
  train_files = [f.decode('utf8') for f in filenames.numpy()]
  # don't train with the _background_noise_ files; exclude when directory name starts with '_'
  train_files = [f for f in train_files if f.split('/')[-2][0] != '_']
  # validation and test files are listed explicitly in *_list.txt; train with everything else
  train_files = list(set(train_files) - set(test_files) - set(val_files))
  # now convert back into a TF tensor so we can use the tf.dataset pipeline
  train_files = tf.constant(train_files)    
  print("Full-speech is in progress.  Good luck!")
else:
  raise ValueError("dataset must be either full-speech or mini-speech")
print('Training set size', len(train_files))
print('Validation set size', len(val_files))
print('Test set size', len(test_files))
# Out:
# Using mini-speech
# Training set size 6400
# Validation set size 800
# Test set size 800

# %%
def decode_audio(audio_binary):
  audio, _ = tf.audio.decode_wav(audio_binary)
  return tf.squeeze(audio, axis=-1)

# %%
# @tf.function
def get_label(file_path):
  parts = tf.strings.split(file_path, os.path.sep)
  in_set = tf.reduce_any(parts[-2] == label_list)
  label = tf.cond(in_set, lambda: parts[-2], lambda: tf.constant(unknown_str))
  # print(f"parts[-2] = {parts[-2]}, in_set = {in_set}, label = {label}")
  # Note: You'll use indexing here instead of tuple unpacking to enable this 
  # to work in a TensorFlow graph.
  return  label # parts[-2]

# %%
def get_waveform_and_label(file_path):
  label = get_label(file_path)
  audio_binary = tf.io.read_file(file_path)
  waveform = decode_audio(audio_binary)
  return waveform, label

# %%
def get_spectrogram(waveform):
  # Concatenate audio with padding so that all audio clips will be of the 
  # same length (16000 samples)
  zero_padding = tf.zeros([wave_length_samps] - tf.shape(waveform), dtype=tf.int16)
  waveform = tf.cast(0.5*waveform*(i16max-i16min), tf.int16)  # scale float [-1,+1]=>INT16
  equal_length = tf.concat([waveform, zero_padding], 0)
  ## Make sure these labels correspond to those used in micro_features_micro_features_generator.cpp
  spectrogram = frontend_op.audio_microfrontend(equal_length, sample_rate=fsamp, num_channels=num_channels,
                                    window_size=window_size_ms, window_step=window_step_ms)
  return spectrogram

# %% [markdown]
# Function to convert each waveform in a set into a spectrogram, then convert those
# back into a dataset using `from_tensor_slices`.  (We should be able to use
# `wav_ds.map(get_spectrogram_and_label_id)`, but there is a problem with that process).

# %%
def create_silence_dataset(num_waves, samples_per_wave, rms_noise_range=[0.01,0.2], silent_label=silence_str):
    # create num_waves waveforms of white gaussian noise, with rms level drawn from rms_noise_range
    # to act as the "silence" dataset
    rng = np.random.default_rng()
    rms_noise_levels = rng.uniform(low=rms_noise_range[0], high=rms_noise_range[1], size=num_waves)
    rand_waves = np.zeros((num_waves, samples_per_wave), dtype=np.float32) # pre-allocate memory
    for i in range(num_waves):
        rand_waves[i,:] = rms_noise_levels[i]*rng.standard_normal(samples_per_wave)
    labels = [silent_label]*num_waves
    return tf.data.Dataset.from_tensor_slices((rand_waves, labels))

# %%
def wavds2specds(waveform_ds):
  wav, label = next(waveform_ds.as_numpy_iterator())
  one_spec = get_spectrogram(wav)
  one_spec = tf.expand_dims(one_spec, axis=0)  # add a 'batch' dimension at the front
  one_spec = tf.expand_dims(one_spec, axis=-1) # add a singleton 'channel' dimension at the back    
  spec_shape = (0,) + one_spec.shape[1:]  # replace the 1st entry in one_spec.shape w/ 0
  spec_grams = np.zeros(spec_shape)
  labels = []
  for wav, label in waveform_ds:
    spectrogram = get_spectrogram(wav)
    # TF conv layer expect inputs structured as 4D (batch_size, height, width, channels)
    # the microfrontend returns 2D tensors (freq, time), so we need to 
    spectrogram = tf.expand_dims(spectrogram, axis=0)  # add a 'batch' dimension at the front
    spectrogram = tf.expand_dims(spectrogram, axis=-1) # add a singleton 'channel' dimension at the back
    spec_grams = np.concatenate((spec_grams, spectrogram))
    new_label = label.numpy().decode('utf8')
    new_label_id = np.argmax(new_label == np.array(label_list))    
    labels.append(new_label_id) # for numeric labels
    # labels.append(new_label) # for string labels
  output_ds = tf.data.Dataset.from_tensor_slices((spec_grams, labels))  
  return output_ds

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
files_ds = tf.data.Dataset.from_tensor_slices(train_files)
waveform_ds = files_ds.map(get_waveform_and_label, num_parallel_calls=AUTOTUNE)
train_ds = wavds2specds(waveform_ds)

# %%
rows = 3
cols = 3
n = rows*cols
fig, axes = plt.subplots(rows, cols, figsize=(10, 12))
for i, (audio, label) in enumerate(waveform_ds.take(n)):
  r = i // cols
  c = i % cols
  ax = axes[r][c]
  ax.plot(audio.numpy())
  ax.set_yticks(np.arange(-1.2, 1.2, 0.2))
  label = label.numpy().decode('utf-8')
  ax.set_title(label)

plt.show()

# %%
for waveform, label in waveform_ds.take(1):
  label = label.numpy().decode('utf-8')
  spectrogram = get_spectrogram(waveform)

print('Label:', label)
print('Waveform shape:', waveform.shape)
print('Spectrogram shape:', spectrogram.shape)
print('Audio playback')
display.display(display.Audio(waveform, rate=16000))
# Out:
# Label: left
# Waveform shape: (16000,)
# Spectrogram shape: (24, 30)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
model(tf.expand_dims(tf.expand_dims(spectrogram, -1), 0).shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-136-58b7bcfaccde> in <module>
# ----> 1 model(tf.expand_dims(tf.expand_dims(spectrogram, -1), 0).shape)
#
# ~/.conda/envs/jeremy_tdk2/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     983
#     984         with ops.enable_auto_cast_variables(self._compute_dtype_object):
# --> 985           outputs = call_fn(inputs, *args, **kwargs)
#     986
#     987         if self._activity_regularizer:
#
# ~/.conda/envs/jeremy_tdk2/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py in call(self, inputs, training, mask)
#     370       if not self.built:
#     371         self._init_graph_network(self.inputs, self.outputs)
# --> 372       return super(Sequential, self).call(inputs, training=training, mask=mask)
#     373
#     374     outputs = inputs  # handle the corner case where self.layers is empty
#
# ~/.conda/envs/jeremy_tdk2/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py in call(self, inputs, training, mask)
#     383         a list of tensors if there are more than one outputs.
#     384     """
# --> 385     return self._run_internal_graph(
#     386         inputs, training=training, mask=mask)
#     387
#
# ~/.conda/envs/jeremy_tdk2/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     482       masks = self._flatten_to_reference_inputs(mask)
#     483     for input_t, mask in zip(inputs, masks):
# --> 484       input_t._keras_mask = mask
#     485
#     486     # Dictionary mapping reference tensors to computed tensors.
#
# AttributeError: 'TensorShape' object has no attribute '_keras_mask'

# %%
def plot_spectrogram(spectrogram, ax):
  # transpose so that the time is
  # represented in the x-axis (columns).
  freq_bins = spectrogram.shape[1]
  time_dur = spectrogram.shape[0]
  X = np.arange(time_dur)
  Y = range(freq_bins)
  ax.pcolormesh(X, Y, spectrogram.T)

fig, axes = plt.subplots(2, figsize=(12, 8))
timescale = np.arange(waveform.shape[0])
axes[0].plot(timescale, waveform.numpy())
axes[0].set_title('Waveform')
axes[0].set_xlim([0, 16000])
plot_spectrogram(spectrogram.numpy(), axes[1])
axes[1].set_title('Spectrogram')
plt.show()
# Out:
# <ipython-input-77-e1cd5567c8a2>:8: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax.pcolormesh(X, Y, spectrogram.T)

# %%
rows = 3
cols = 3
n = rows*cols
fig, axes = plt.subplots(rows, cols, figsize=(10, 10))
for i, (spectrogram, label_id) in enumerate(train_ds.take(n)):
  r = i // cols
  c = i % cols
  ax = axes[r][c]
  plot_spectrogram(np.squeeze(spectrogram.numpy()), ax)
  ax.set_title(label_list[label_id.numpy()])
  ax.axis('off')

plt.show()
# Out:
# <ipython-input-77-e1cd5567c8a2>:8: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax.pcolormesh(X, Y, spectrogram.T)

# %%
def copy_with_noise(ds_input, rms_level=0.25):
  rng = tf.random.Generator.from_seed(1234)
  wave_shape = tf.constant((wave_length_samps,))
  def add_noise(waveform, label):
    noise = rms_level*rng.normal(shape=wave_shape)
    zero_padding = tf.zeros([wave_length_samps] - tf.shape(waveform), dtype=tf.float32)
    waveform = tf.concat([waveform, zero_padding], 0)    
    noisy_wave = waveform + noise
    return noisy_wave, label

  return ds_input.map(add_noise)

# %%
# waveform_ds = augment_with_noise(waveform_ds)
count = 0
for w,l in waveform_ds:
  if w.shape != (16000,):
    print(f"element {count} has shape {w.shape}")
    break
  count += 1
print(count)
# Out:
# element 20 has shape (11146,)
# 20

# %%
def pad_16000(waveform, label):
    zero_padding = tf.zeros([wave_length_samps] - tf.shape(waveform), dtype=tf.float32)
    waveform = tf.concat([waveform, zero_padding], 0)        
    return waveform, label

# %%
def count_labels(dataset):
    counts = {}
    for _, lbl in dataset:
        if lbl.dtype == tf.string:
            label = lbl.numpy().decode('utf-8')
        else:
            label = lbl.numpy()
        if label in counts:
            counts[label] += 1
        else:
            counts[label] = 1
    return counts

# %%
# Collect what we did to generate the training dataset into a 
# function, so we can repeat with the validation and test sets.
def preprocess_dataset(files, num_silent=None, noisy_reps_of_known=None):
  # if noisy_reps_of_known is not None, it should be a list of rms noise levels
  # For every target word in the data set, 1 copy will be created with each level 
  # of noise added to it.  So [0.1, 0.2] will add 2x noisy copies of the target words 
  if num_silent is None:
    num_silent = int(0.2*len(files))+1
  files_ds = tf.data.Dataset.from_tensor_slices(files)
  waveform_ds = files_ds.map(get_waveform_and_label)
  if noisy_reps_of_known is not None:
    # create a few copies of only the target words to balance the distribution
    # create a tmp dataset with only the target words
    ds_only_cmds = waveform_ds.filter(lambda w,l: tf.reduce_any(l == commands))
    for noise_level in noisy_reps_of_known:
       waveform_ds = waveform_ds.concatenate(copy_with_noise(ds_only_cmds, rms_level=noise_level))
  if num_silent > 0:
    silent_wave_ds = create_silence_dataset(num_silent, wave_length_samps, 
                                            rms_noise_range=[0.01,0.2], 
                                            silent_label=silence_str)
    waveform_ds = waveform_ds.concatenate(silent_wave_ds)
  output_ds = wavds2specds(waveform_ds)
  return output_ds

# %%
print(f"We have {len(train_files)}/{len(val_files)}/{len(test_files)} training/validation/test files")
# Out:
# We have 6400/800/800 training/validation/test files

# %%
# print(train_files[:20])
print(label_list)
train_files[:20]

tmp_ds = preprocess_dataset(train_files[:20])
print(count_labels(tmp_ds))

tmp_ds = preprocess_dataset(train_files[:20], noisy_reps_of_known=[0.05,0.1])
print(count_labels(tmp_ds))
# Out:
# ['_silence', '_unknown', 'left', 'right']
# {1: 15, 3: 5, 0: 5}
# {1: 15, 3: 15, 0: 5}

# %%
train_ds = preprocess_dataset(train_files, noisy_reps_of_known=[0.05,0.1,0.15,0.2,0.25])
val_ds = preprocess_dataset(val_files)
test_ds = preprocess_dataset(test_files)

# %%
print("training data set")
print(count_labels(train_ds))
print("val_ds data set")
print(count_labels(val_ds))
print("test_ds data set")
print(count_labels(test_ds))
# Out:
# training data set
# {1: 4762, 3: 4974, 2: 4854, 0: 1281}
# val_ds data set
# {1: 630, 2: 88, 3: 82, 0: 161}
# test_ds data set
# {3: 89, 1: 608, 2: 103, 0: 161}

# %%
train_ds = train_ds.shuffle(int(len(train_files)*1.2))
val_ds = val_ds.shuffle(int(len(val_files)*1.2))
test_ds = test_ds.shuffle(int(len(test_files)*1.2))

# %%
batch_size = 64
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# %%
train_ds = train_ds.cache().prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)

# %%
for spectrogram, _ in train_ds.take(1):
  spec1 = spectrogram
# take(1) takes 1 *batch*, so we have to select the first 
# spectrogram from it, hence the [0]
print(f"Spectrogram shape {spec1[0].shape}")
print(f"ranges from {np.min(spec1)} to {np.max(spec1)}")   # min/max across the whole batch
# Out:
# Spectrogram shape (24, 30, 1)
# ranges from 0.0 to 712.0

# %%
for spectrogram, _ in train_ds.take(1):
  # take(1) takes 1 *batch*, so we have to select the first 
  # spectrogram from it, hence the [0]
  input_shape = spectrogram[0].shape  
print('Input shape:', input_shape)
num_labels = len(label_list)
# Out:
# Input shape: (24, 30, 1)

# %%
layers.MaxPooling2D?

# %%
## print('Input shape:', input_shape)
model = models.Sequential([
    layers.Input(shape=input_shape),
    layers.Conv2D(20, 3, activation='relu'),
    layers.MaxPooling2D(name='pool2', pool_size=(4,4)),
    layers.DepthwiseConv2D(kernel_size=(3,3), padding='same'),
    layers.Conv2D(20, 1, activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Dropout(0.2),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(num_labels),
], name="simple_cnn")

model.summary()
# Out:
# Model: "simple_cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_22 (Conv2D)           (None, 22, 28, 20)        200
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 5, 7, 20)          0
# _________________________________________________________________
# depthwise_conv2d_11 (Depthwi (None, 5, 7, 20)          200
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 5, 7, 20)          420
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 2, 3, 20)          0
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 2, 3, 20)          0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 120)               0
# _________________________________________________________________
# dense_33 (Dense)             (None, 128)               15488
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_34 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_35 (Dense)             (None, 4)                 516
# =================================================================
# Total params: 33,336
# Trainable params: 33,336
# Non-trainable params: 0
# _________________________________________________________________

# %%
# number of MACs in each layer is (# outputs in layer) * (number of inputs that contribute to one output)
macs = np.array([(22*28*20)*(3*3), (5*7*20)*(3*3), (5*7*20)*20, 120*128, 128*128, 4*128])
print(macs)
print(np.sum(macs))
# Out:
# [110880   6300  14000  15360  16384    512]
# 163436

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

# %%
#  Google: feature extraction with Keras
# feature_model = tf.keras.model(input=model.input, output= model.layers[4].output)

# %%
history = model.fit(
    train_ds, 
    validation_data=val_ds,  
    epochs=EPOCHS) 
    # callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=2))
# Out:
# Epoch 1/50
# 248/248 [==============================] - 1s 3ms/step - loss: 2.6867 - accuracy: 0.4429 - val_loss: 0.8497 - val_accuracy: 0.5786
# Epoch 2/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.9905 - accuracy: 0.5184 - val_loss: 0.6948 - val_accuracy: 0.6701
# Epoch 3/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.9070 - accuracy: 0.5446 - val_loss: 0.7004 - val_accuracy: 0.6764
# Epoch 4/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.8365 - accuracy: 0.5779 - val_loss: 0.6617 - val_accuracy: 0.7045
# Epoch 5/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.8113 - accuracy: 0.5889 - val_loss: 0.6862 - val_accuracy: 0.7929
# Epoch 6/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.7734 - accuracy: 0.6172 - val_loss: 0.5444 - val_accuracy: 0.8304
# Epoch 7/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.7382 - accuracy: 0.6421 - val_loss: 0.5589 - val_accuracy: 0.8127
# Epoch 8/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.7165 - accuracy: 0.6472 - val_loss: 0.5524 - val_accuracy: 0.8169
# Epoch 9/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.6903 - accuracy: 0.6632 - val_loss: 0.4783 - val_accuracy: 0.8439
# Epoch 10/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.6767 - accuracy: 0.6734 - val_loss: 0.5120 - val_accuracy: 0.8002
# Epoch 11/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.6585 - accuracy: 0.6835 - val_loss: 0.4683 - val_accuracy: 0.8366
# Epoch 12/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.6425 - accuracy: 0.6901 - val_loss: 0.4596 - val_accuracy: 0.8564
# Epoch 13/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.6272 - accuracy: 0.6994 - val_loss: 0.4209 - val_accuracy: 0.8699
# Epoch 14/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.6145 - accuracy: 0.7048 - val_loss: 0.4450 - val_accuracy: 0.8335
# Epoch 15/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.6115 - accuracy: 0.7061 - val_loss: 0.4550 - val_accuracy: 0.8502
# Epoch 16/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.6033 - accuracy: 0.7068 - val_loss: 0.4182 - val_accuracy: 0.8564
# Epoch 17/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.6021 - accuracy: 0.7153 - val_loss: 0.4303 - val_accuracy: 0.8626
# Epoch 18/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.5871 - accuracy: 0.7218 - val_loss: 0.4299 - val_accuracy: 0.8533
# Epoch 19/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.5852 - accuracy: 0.7233 - val_loss: 0.4543 - val_accuracy: 0.8283
# Epoch 20/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.5779 - accuracy: 0.7276 - val_loss: 0.4009 - val_accuracy: 0.8595
# Epoch 21/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.5681 - accuracy: 0.7327 - val_loss: 0.4813 - val_accuracy: 0.8304
# Epoch 22/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.5544 - accuracy: 0.7390 - val_loss: 0.3977 - val_accuracy: 0.8887
# Epoch 23/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.5564 - accuracy: 0.7426 - val_loss: 0.4185 - val_accuracy: 0.8574
# Epoch 24/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.5609 - accuracy: 0.7391 - val_loss: 0.4104 - val_accuracy: 0.8574
# Epoch 25/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.5437 - accuracy: 0.7445 - val_loss: 0.3869 - val_accuracy: 0.8772
# Epoch 26/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.5416 - accuracy: 0.7455 - val_loss: 0.3948 - val_accuracy: 0.8814
# Epoch 27/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.5343 - accuracy: 0.7534 - val_loss: 0.3890 - val_accuracy: 0.8835
# Epoch 28/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.5350 - accuracy: 0.7507 - val_loss: 0.4249 - val_accuracy: 0.8377
# Epoch 29/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.5279 - accuracy: 0.7528 - val_loss: 0.4062 - val_accuracy: 0.8647
# Epoch 30/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.5245 - accuracy: 0.7529 - val_loss: 0.3709 - val_accuracy: 0.8918
# Epoch 31/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.5272 - accuracy: 0.7568 - val_loss: 0.4170 - val_accuracy: 0.8658
# Epoch 32/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.5227 - accuracy: 0.7594 - val_loss: 0.3988 - val_accuracy: 0.8595
# Epoch 33/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.5208 - accuracy: 0.7586 - val_loss: 0.4066 - val_accuracy: 0.8626
# Epoch 34/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.5128 - accuracy: 0.7626 - val_loss: 0.4145 - val_accuracy: 0.8491
# Epoch 35/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.5108 - accuracy: 0.7642 - val_loss: 0.4088 - val_accuracy: 0.8502
# Epoch 36/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.5121 - accuracy: 0.7621 - val_loss: 0.4129 - val_accuracy: 0.8491
# Epoch 37/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.5121 - accuracy: 0.7612 - val_loss: 0.4110 - val_accuracy: 0.8585
# Epoch 38/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.5126 - accuracy: 0.7649 - val_loss: 0.4007 - val_accuracy: 0.8574
# Epoch 39/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.4967 - accuracy: 0.7649 - val_loss: 0.4077 - val_accuracy: 0.8439
# Epoch 40/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.5006 - accuracy: 0.7664 - val_loss: 0.3981 - val_accuracy: 0.8606
# Epoch 41/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.4927 - accuracy: 0.7678 - val_loss: 0.4221 - val_accuracy: 0.8439
# Epoch 42/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.4919 - accuracy: 0.7682 - val_loss: 0.3596 - val_accuracy: 0.8907
# Epoch 43/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.4934 - accuracy: 0.7723 - val_loss: 0.4206 - val_accuracy: 0.8366
# Epoch 44/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.4914 - accuracy: 0.7741 - val_loss: 0.4592 - val_accuracy: 0.8023
# Epoch 45/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.5030 - accuracy: 0.7656 - val_loss: 0.3781 - val_accuracy: 0.8824
# Epoch 46/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.4819 - accuracy: 0.7741 - val_loss: 0.3943 - val_accuracy: 0.8658
# Epoch 47/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.4817 - accuracy: 0.7749 - val_loss: 0.4073 - val_accuracy: 0.8606
# Epoch 48/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.4974 - accuracy: 0.7676 - val_loss: 0.4327 - val_accuracy: 0.8283
# Epoch 49/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.4831 - accuracy: 0.7744 - val_loss: 0.3770 - val_accuracy: 0.8730
# Epoch 50/50
# 248/248 [==============================] - 1s 2ms/step - loss: 0.4949 - accuracy: 0.7686 - val_loss: 0.3705 - val_accuracy: 0.8887

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
metrics = history.history
plt.subplot(2,1,1)
plt.semilogy(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['training', 'validation'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.subplot(2,1,2)
plt.plot(history.epoch, metrics['accuracy'], metrics['val_accuracy'])
plt.legend(['training', 'validation'])
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
test_audio = []
test_labels = []

for audio, label in test_ds:
  test_audio.append(audio.numpy())
  test_labels.append(label.numpy())

test_audio = np.array(test_audio)
test_labels = np.array(test_labels)

# %%
y_pred = np.argmax(model.predict(test_audio), axis=1)
y_true = test_labels

test_acc = sum(y_pred == y_true) / len(y_true)
print(f'Test set accuracy: {test_acc:.0%}')
# Out:
# Test set accuracy: 90%

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred) 
plt.figure(figsize=(6, 6))
sns.heatmap(confusion_mtx, xticklabels=label_list, yticklabels=label_list, 
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %%
dset = train_ds.unbatch()

ds_audio = []
ds_labels = []

for audio, label in dset:
  ds_audio.append(audio.numpy())
  ds_labels.append(label.numpy())

ds_labels = np.array(ds_labels)
ds_audio = np.array(ds_audio)

model_out = model.predict(ds_audio)
y_pred = np.argmax(model_out, axis=1)
y_true = ds_labels

ds_acc = sum(y_pred == y_true) / len(y_true)
print(f'Data set accuracy: {ds_acc:.0%}')

confusion_mtx = tf.math.confusion_matrix(y_true, y_pred) 
plt.figure(figsize=(5,4))
sns.heatmap(confusion_mtx, xticklabels=label_list, yticklabels=label_list, 
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()
# Out:
# Data set accuracy: 79%

# %%
sample_files = [data_dir/'left/07ad9b59_nohash_0.wav', 
                data_dir/'no/01bb6a2a_nohash_0.wav',  
                data_dir/'right/0362539c_nohash_1.wav',
                data_dir/'right/b5d1e505_nohash_0.wav']
fstr_list = [str(f) for f in sample_files]
sample_ds = preprocess_dataset(fstr_list, num_silent=1)
count = 1
for spectrogram, label in sample_ds.batch(1):
  prediction = model(spectrogram)
  plt.subplot(len(sample_files)+1, 1, count)
  plt.bar(label_list, tf.nn.softmax(prediction[0]))
  plt.title(f'Predictions for "{label_list[label[0]]}"')
  plt.show()
  count += 1

# %% [markdown]
# ## Quantize and Convert to TFLite

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# %%
num_calibration_steps = 10
ds_iter = val_ds.unbatch().batch(1).as_numpy_iterator()
def representative_dataset_gen():
  for _ in range(num_calibration_steps):
    next_input = next(ds_iter)[0]
    next_input = next_input.astype(np.float32)  # (DIFF_FROM_LECTURE)
    yield [next_input]

# %%
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8  # or tf.uint8; should match dat_q in eval_quantized_model.py
converter.inference_output_type = tf.int8  # or tf.uint8

# %%
tflite_quant_model = converter.convert()
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpnqo8dcz8/assets
# INFO:tensorflow:Assets written to: /tmp/tmpnqo8dcz8/assets

# %%
fname = 'kws_model.tflite'
with open(fname, "wb") as fpo:
  num_bytes_written = fpo.write(tflite_quant_model)
print(f"Wrote {num_bytes_written} / {len(tflite_quant_model)} bytes to tflite file")
# Out:
# Wrote 41504 / 41504 bytes to tflite file

# %%
# !xxd -i kws_model.tflite
# Out:
# unsigned char kws_model_tflite[] = {
#   0x1c, 0x00, 0x00, 0x00, 0x54, 0x46, 0x4c, 0x33, 0x00, 0x00, 0x12, 0x00,
#   0x1c, 0x00, 0x04, 0x00, 0x08, 0x00, 0x0c, 0x00, 0x10, 0x00, 0x14, 0x00,
#   0x00, 0x00, 0x18, 0x00, 0x12, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00,
#   0x8c, 0xa1, 0x00, 0x00, 0x78, 0x88, 0x00, 0x00, 0x60, 0x88, 0x00, 0x00,
#   0x3c, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x0c, 0x00, 0x00, 0x00, 0x08, 0x00, 0x0c, 0x00, 0x04, 0x00, 0x08, 0x00,
#   0x08, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00, 0x18, 0x00, 0x00, 0x00,
#   0x13, 0x00, 0x00, 0x00, 0x6d, 0x69, 0x6e, 0x5f, 0x72, 0x75, 0x6e, 0x74,
#   0x69, 0x6d, 0x65, 0x5f, 0x76, 0x65, 0x72, 0x73, 0x69, 0x6f, 0x6e, 0x00,
#   0x19, 0x00, 0x00, 0x00, 0x0c, 0x88, 0x00, 0x00, 0xf8, 0x87, 0x00, 0x00,
#   0x8c, 0x87, 0x00, 0x00, 0x18, 0x87, 0x00, 0x00, 0x04, 0x85, 0x00, 0x00,
#   0xf0, 0x82, 0x00, 0x00, 0xcc, 0x82, 0x00, 0x00, 0xa8, 0x82, 0x00, 0x00,
#   0x94, 0x46, 0x00, 0x00, 0x80, 0x06, 0x00, 0x00, 0x6c, 0x04, 0x00, 0x00,
#   0xa8, 0x03, 0x00, 0x00, 0xe4, 0x02, 0x00, 0x00, 0x40, 0x01, 0x00, 0x00,
#   0xdc, 0x00, 0x00, 0x00, 0xd0, 0x00, 0x00, 0x00, 0xbc, 0x00, 0x00, 0x00,
#   0xa8, 0x00, 0x00, 0x00, 0x94, 0x00, 0x00, 0x00, 0x80, 0x00, 0x00, 0x00,
#   0x6c, 0x00, 0x00, 0x00, 0x58, 0x00, 0x00, 0x00, 0x44, 0x00, 0x00, 0x00,
#   0x30, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0xd6, 0x78, 0xff, 0xff,
#   0x04, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0x31, 0x2e, 0x35, 0x2e,
#   0x30, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x74, 0x64, 0xff, 0xff, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x84, 0x64, 0xff, 0xff, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x94, 0x64, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0xa4, 0x64, 0xff, 0xff, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0xb4, 0x64, 0xff, 0xff, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0xc4, 0x64, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0xd4, 0x64, 0xff, 0xff, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0xe4, 0x64, 0xff, 0xff, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0xf4, 0x64, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x00, 0x86, 0x79, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00,
#   0x50, 0x00, 0x00, 0x00, 0x70, 0x00, 0x00, 0x00, 0xfb, 0xff, 0xff, 0xff,
#   0xc7, 0xff, 0xff, 0xff, 0xd6, 0xff, 0xff, 0xff, 0xcb, 0xff, 0xff, 0xff,
#   0x2f, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0xbb, 0xff, 0xff, 0xff, 0xb5, 0xff, 0xff, 0xff, 0xf3, 0xff, 0xff, 0xff,
#   0xca, 0xff, 0xff, 0xff, 0x27, 0x00, 0x00, 0x00, 0xcf, 0xff, 0xff, 0xff,
#   0x36, 0x00, 0x00, 0x00, 0xcc, 0xff, 0xff, 0xff, 0xb2, 0xff, 0xff, 0xff,
#   0x17, 0x00, 0x00, 0x00, 0xcf, 0xff, 0xff, 0xff, 0x96, 0xff, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x00, 0xe6, 0x79, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00,
#   0x90, 0x01, 0x00, 0x00, 0xb0, 0x0c, 0xf4, 0x64, 0xac, 0x21, 0xc3, 0xd0,
#   0x11, 0xd6, 0x27, 0x7f, 0x04, 0x3e, 0x6b, 0xe7, 0xf1, 0x1b, 0x42, 0x26,
#   0x99, 0x34, 0x3e, 0x4c, 0xe1, 0x0e, 0x56, 0x81, 0x2b, 0x32, 0xe6, 0x15,
#   0xb7, 0xfd, 0x2e, 0x32, 0x25, 0x95, 0x1e, 0xf8, 0x88, 0x7f, 0x11, 0x17,
#   0x47, 0x2a, 0x6e, 0xfc, 0xdc, 0x1b, 0xf7, 0xfe, 0x96, 0x74, 0xbf, 0x1e,
#   0x62, 0xb9, 0x73, 0x13, 0xe9, 0x29, 0x3e, 0xf8, 0x0a, 0xda, 0xec, 0xcc,
#   0x81, 0x2c, 0x4a, 0x15, 0x19, 0xea, 0x10, 0xf4, 0xa3, 0xd9, 0xfb, 0xed,
#   0x13, 0x93, 0x5c, 0x44, 0xff, 0x2f, 0x0d, 0x28, 0x7f, 0x56, 0x58, 0xef,
#   0x2d, 0xc8, 0xd7, 0xcd, 0xc4, 0x21, 0x5b, 0x6d, 0x8e, 0x1c, 0x23, 0x73,
#   0x24, 0xc8, 0xf7, 0xac, 0xcc, 0x81, 0x02, 0x19, 0xcd, 0x32, 0xc4, 0x7e,
#   0x4b, 0xba, 0xe0, 0x1a, 0x3e, 0x44, 0x3b, 0x19, 0xfa, 0xd5, 0x81, 0x28,
#   0x33, 0xfd, 0x4d, 0x5a, 0x1e, 0x24, 0x7e, 0xfe, 0xf8, 0xc3, 0x0a, 0x3d,
#   0xd9, 0x38, 0xb8, 0xf8, 0x55, 0xee, 0x63, 0xee, 0x7f, 0xd0, 0x24, 0x8f,
#   0x05, 0xf4, 0x16, 0xae, 0x40, 0x9d, 0x26, 0xfa, 0xc7, 0xed, 0x55, 0x32,
#   0x7f, 0x87, 0xf3, 0xd7, 0xcb, 0xbf, 0x08, 0x49, 0xea, 0xf7, 0x96, 0x77,
#   0x50, 0xf8, 0xc4, 0x43, 0xf0, 0x7f, 0xaf, 0xca, 0xc8, 0xd1, 0x03, 0x4a,
#   0x1f, 0xdd, 0x42, 0x13, 0x1a, 0x1c, 0x2e, 0x27, 0xf4, 0xae, 0x1d, 0x7b,
#   0xf5, 0x45, 0x7f, 0x01, 0xf5, 0x01, 0x3c, 0xdd, 0x22, 0x13, 0x45, 0xab,
#   0x1c, 0xa9, 0x21, 0x22, 0x3b, 0xa4, 0x41, 0xda, 0x81, 0xce, 0xed, 0x1c,
#   0x1a, 0x02, 0x03, 0xe9, 0x55, 0x9c, 0xc5, 0x11, 0x32, 0xca, 0xf1, 0x04,
#   0xe4, 0xf7, 0x48, 0xf5, 0x1c, 0xc4, 0x53, 0xfe, 0xdf, 0x0a, 0x16, 0x07,
#   0x67, 0x44, 0x7f, 0xf1, 0x29, 0xdf, 0xc0, 0xda, 0xd6, 0x50, 0x32, 0x2c,
#   0xda, 0xbf, 0xca, 0xcf, 0xd5, 0x0f, 0xe2, 0xe7, 0x45, 0x4f, 0x05, 0x03,
#   0x4f, 0xea, 0x38, 0xa8, 0x61, 0x7f, 0x1d, 0x1b, 0xa2, 0x4c, 0x16, 0x62,
#   0xfc, 0x51, 0x2f, 0xd0, 0xb2, 0x28, 0xd8, 0xc9, 0x81, 0x30, 0x32, 0x5f,
#   0xf0, 0xfd, 0x4c, 0x67, 0x1b, 0x05, 0x1c, 0x15, 0xd5, 0xee, 0x01, 0x74,
#   0x72, 0x49, 0xc1, 0xbe, 0xbb, 0x04, 0x0e, 0xf7, 0x7f, 0x29, 0x34, 0x39,
#   0xd1, 0xf1, 0x44, 0xd3, 0xf7, 0xf5, 0xc4, 0xec, 0x05, 0x30, 0x7f, 0x20,
#   0xe6, 0xd8, 0xe3, 0xd9, 0xd3, 0x0d, 0xd2, 0x2d, 0x40, 0x4d, 0x1a, 0x21,
#   0xc1, 0xbb, 0x39, 0x0e, 0x95, 0xbd, 0x2c, 0x2f, 0xe1, 0x11, 0x81, 0x3a,
#   0xec, 0x3b, 0x40, 0x34, 0x1a, 0x3a, 0xee, 0x50, 0x63, 0x12, 0xc2, 0xcf,
#   0x95, 0x05, 0x54, 0xf0, 0xe8, 0x1e, 0xb8, 0x7f, 0x77, 0xc5, 0x12, 0x7f,
#   0x2a, 0xd7, 0xc7, 0xed, 0xab, 0xac, 0xb4, 0xbb, 0x27, 0xd7, 0x1f, 0x46,
#   0x7f, 0x69, 0xdc, 0x88, 0xea, 0x16, 0x4b, 0x46, 0x00, 0x00, 0x00, 0x00,
#   0x86, 0x7b, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00, 0xb4, 0x00, 0x00, 0x00,
#   0x1a, 0x1c, 0xe6, 0x36, 0xe9, 0xf3, 0xee, 0x18, 0x07, 0xd5, 0x08, 0x49,
#   0xee, 0x81, 0xbb, 0x0a, 0x26, 0x07, 0x15, 0x8d, 0x21, 0x3a, 0x16, 0xf9,
#   0xef, 0x30, 0x01, 0xe8, 0xc2, 0xe6, 0x36, 0xe7, 0xe8, 0x30, 0xd9, 0xe5,
#   0x0b, 0x6a, 0xdc, 0xb7, 0xcc, 0xfd, 0xf8, 0xc8, 0x33, 0xa2, 0x51, 0x5c,
#   0xb7, 0xcf, 0xde, 0x3a, 0x10, 0xd4, 0x3d, 0x81, 0x7f, 0xfd, 0x68, 0xbc,
#   0xf7, 0xfa, 0x43, 0xf0, 0xc6, 0xfa, 0x7f, 0x58, 0x88, 0x20, 0x62, 0xb9,
#   0x25, 0x41, 0x18, 0xf8, 0x23, 0xa1, 0xb5, 0x81, 0x74, 0xc2, 0x14, 0x04,
#   0x8a, 0x49, 0x34, 0x09, 0x39, 0xe6, 0x41, 0xf5, 0x76, 0xfb, 0xac, 0x78,
#   0xc4, 0x1b, 0x95, 0xc7, 0x82, 0x1e, 0xb3, 0x81, 0xe2, 0x7f, 0xa3, 0x7f,
#   0x19, 0xa9, 0x81, 0xf4, 0x81, 0x55, 0xcd, 0xe5, 0x8d, 0x1a, 0xe5, 0xa9,
#   0x2d, 0xce, 0x26, 0xea, 0x7f, 0x4c, 0x2e, 0x59, 0xea, 0x68, 0x00, 0xbc,
#   0xe7, 0xf9, 0x0d, 0xe3, 0xea, 0x81, 0x12, 0xcf, 0x7f, 0x81, 0xc3, 0x10,
#   0x5d, 0xd4, 0xe4, 0xc4, 0x7f, 0x7f, 0xc3, 0x96, 0xeb, 0x8e, 0x7f, 0x29,
#   0xb7, 0x04, 0xf2, 0x02, 0x02, 0x47, 0x81, 0x0c, 0xe4, 0x8f, 0xb3, 0x59,
#   0x58, 0x52, 0xd3, 0x7f, 0x16, 0x4d, 0x36, 0x77, 0xb9, 0x10, 0x81, 0x45,
#   0x46, 0x7c, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00, 0xb4, 0x00, 0x00, 0x00,
#   0x1b, 0xd3, 0x20, 0xd6, 0xe8, 0x10, 0x37, 0x7f, 0x64, 0x00, 0x7f, 0x6a,
#   0x26, 0x48, 0xf2, 0x49, 0xf1, 0xb5, 0xbc, 0x62, 0x7f, 0x5a, 0xac, 0x82,
#   0x30, 0xc0, 0x39, 0x34, 0x81, 0xf2, 0x52, 0xea, 0x03, 0xee, 0xa4, 0x12,
#   0x7f, 0xab, 0x17, 0xe6, 0x93, 0x15, 0xed, 0xd9, 0x2d, 0x3c, 0x44, 0x13,
#   0x0c, 0x3b, 0x7f, 0xbf, 0xd0, 0xbd, 0xee, 0x81, 0xeb, 0xf1, 0xf7, 0x00,
#   0x45, 0x33, 0x27, 0xfb, 0xd5, 0xd3, 0xa8, 0xf3, 0xe0, 0x35, 0x13, 0x7f,
#   0x7f, 0x0c, 0xd6, 0x13, 0xe1, 0xcf, 0xcd, 0xe9, 0xdb, 0xd0, 0xd1, 0x3d,
#   0x07, 0x3a, 0xf8, 0x7f, 0xfa, 0xa0, 0x11, 0x08, 0x7f, 0x33, 0x37, 0x54,
#   0x73, 0x7a, 0xc3, 0xd0, 0xe0, 0xf0, 0x4a, 0x13, 0x23, 0x2b, 0x7f, 0x03,
#   0xac, 0xc2, 0xfb, 0xd4, 0xe4, 0xf2, 0x58, 0x60, 0x7f, 0x1b, 0x43, 0x43,
#   0xf6, 0x0a, 0xae, 0x7f, 0xde, 0x48, 0x85, 0xa6, 0xc2, 0xf7, 0x21, 0x4c,
#   0x53, 0x7f, 0x31, 0xfd, 0x2c, 0x7f, 0xcb, 0xff, 0x26, 0xc4, 0xd2, 0xe6,
#   0x6f, 0xaf, 0x51, 0x7f, 0x9b, 0xb8, 0x4a, 0x93, 0xf3, 0x94, 0x3b, 0xdf,
#   0xea, 0xab, 0x72, 0x81, 0x0c, 0x17, 0x7f, 0xf5, 0xb9, 0x35, 0x66, 0xc7,
#   0xd3, 0x31, 0x3a, 0x3c, 0xc5, 0x7f, 0xd2, 0xe0, 0xd4, 0x0b, 0xb6, 0xa5,
#   0x06, 0x7d, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00,
#   0x0b, 0xe5, 0x35, 0xec, 0x19, 0xe1, 0x05, 0xf8, 0xdf, 0xff, 0x22, 0x20,
#   0xf0, 0xf0, 0xaf, 0xde, 0x01, 0x1a, 0x9c, 0x02, 0x04, 0x21, 0x16, 0xf0,
#   0xe9, 0xd5, 0x25, 0x0e, 0xed, 0xdf, 0xdc, 0xaa, 0xf4, 0xd2, 0xdc, 0x18,
#   0x23, 0x00, 0xcf, 0x07, 0x13, 0xec, 0xf0, 0xec, 0x1b, 0x19, 0xe2, 0x12,
#   0xfa, 0xe9, 0xc4, 0xf7, 0x26, 0xe2, 0xeb, 0xdf, 0xd7, 0x0c, 0xe6, 0xde,
#   0x00, 0x19, 0xfa, 0xbb, 0x05, 0xea, 0x16, 0xf0, 0xff, 0xe7, 0xd8, 0xa5,
#   0xf5, 0xeb, 0xda, 0xd5, 0x15, 0x1c, 0x00, 0xc9, 0xe3, 0x20, 0x1a, 0xd6,
#   0xf8, 0xde, 0xc5, 0xe3, 0xaa, 0xf8, 0xda, 0xf7, 0xda, 0x03, 0xe6, 0xc2,
#   0xc2, 0x18, 0x0f, 0x1f, 0xf0, 0xed, 0x14, 0x01, 0xdc, 0xe2, 0xce, 0x18,
#   0xf0, 0x10, 0x0c, 0xdf, 0x11, 0x0d, 0x81, 0xfe, 0xf2, 0x12, 0x25, 0xf9,
#   0xe6, 0xfb, 0xb9, 0xe9, 0x07, 0xbc, 0x14, 0x00, 0xfb, 0x0d, 0x25, 0x05,
#   0xa6, 0x05, 0x13, 0x14, 0xd8, 0xf6, 0xa2, 0xd9, 0x0c, 0xe5, 0x15, 0x13,
#   0xd0, 0xe0, 0xf3, 0xfb, 0xfd, 0x0a, 0x14, 0xe0, 0xfb, 0x24, 0xe7, 0xf0,
#   0xf6, 0x01, 0xef, 0x10, 0x17, 0xd8, 0x19, 0xc8, 0xfa, 0x01, 0x1b, 0xcd,
#   0xc3, 0x15, 0xe9, 0x23, 0xdd, 0xde, 0x14, 0xed, 0x01, 0x18, 0xf6, 0xf2,
#   0xc4, 0x10, 0xf1, 0xee, 0xf1, 0xfe, 0x1b, 0x18, 0xef, 0xfa, 0xf6, 0x0f,
#   0x0f, 0xe2, 0x0e, 0xe8, 0x0f, 0x03, 0x0a, 0xfc, 0x06, 0xf9, 0xf6, 0x06,
#   0x01, 0x02, 0x1d, 0x05, 0xd4, 0xc3, 0xfb, 0xdb, 0x1e, 0x06, 0xf6, 0xfb,
#   0x01, 0x26, 0xfa, 0xe6, 0x13, 0xf1, 0x06, 0xff, 0xeb, 0x13, 0x0b, 0xf0,
#   0x16, 0xf6, 0xd9, 0xf6, 0xf3, 0xfb, 0x09, 0x20, 0xe3, 0x05, 0x1b, 0x14,
#   0x00, 0x15, 0x17, 0xe9, 0x1c, 0xf8, 0x13, 0x01, 0xf0, 0xf4, 0x19, 0x0c,
#   0xe2, 0x15, 0xfb, 0xf9, 0x10, 0x0e, 0x1a, 0x06, 0x12, 0x11, 0x10, 0x13,
#   0xee, 0xe7, 0x1f, 0x1b, 0xea, 0x0c, 0x0a, 0x15, 0xf6, 0x11, 0xf8, 0xf8,
#   0x16, 0x05, 0x16, 0xe4, 0xf2, 0x1d, 0xf5, 0x06, 0x0c, 0x0d, 0xe6, 0x0a,
#   0x18, 0xed, 0x12, 0x13, 0xed, 0xfd, 0x19, 0x0d, 0x10, 0x0e, 0x00, 0x24,
#   0x0e, 0xdb, 0xf3, 0xe8, 0x0d, 0xfc, 0xfc, 0xf7, 0x23, 0x07, 0x10, 0xf1,
#   0xfe, 0x03, 0x13, 0x08, 0xf7, 0x09, 0xec, 0x03, 0xf6, 0xe5, 0x08, 0xde,
#   0x11, 0x0f, 0x0f, 0xf9, 0xea, 0x14, 0x0c, 0x11, 0xf1, 0x15, 0xff, 0x06,
#   0xd9, 0x1d, 0xf4, 0xeb, 0x16, 0x04, 0xf2, 0x0c, 0xf4, 0x18, 0xfe, 0xf0,
#   0x09, 0x13, 0x18, 0x0c, 0xfe, 0x04, 0xfc, 0x1b, 0x16, 0xe9, 0x16, 0x15,
#   0xe8, 0x08, 0xf9, 0x21, 0xf1, 0x08, 0x1f, 0xfa, 0xf8, 0xfc, 0x15, 0xe5,
#   0x04, 0xf2, 0x19, 0xee, 0xe1, 0x03, 0x16, 0x19, 0xed, 0x0c, 0x1e, 0xf0,
#   0xd5, 0x15, 0x1a, 0xfa, 0x18, 0x11, 0xff, 0xf9, 0xef, 0xfa, 0x20, 0x1d,
#   0x07, 0x0e, 0x14, 0xf5, 0xfe, 0x08, 0xfe, 0xde, 0x1c, 0x14, 0xfd, 0xf1,
#   0x04, 0x15, 0x13, 0x0a, 0x06, 0x11, 0xe3, 0x0a, 0x03, 0xe6, 0x1c, 0x0d,
#   0xe3, 0xe1, 0x0a, 0x0b, 0x13, 0xfd, 0x18, 0x0a, 0xf7, 0xe8, 0xfd, 0x04,
#   0x00, 0x04, 0xec, 0xf0, 0x1b, 0xfc, 0x0d, 0xfd, 0xfa, 0xe9, 0x19, 0xf2,
#   0xd9, 0x24, 0xfd, 0xe6, 0x0a, 0x03, 0xf8, 0xe9, 0x01, 0xfc, 0x10, 0xec,
#   0xe3, 0xe7, 0x14, 0x0d, 0xe6, 0x0c, 0x13, 0x05, 0xe9, 0x1b, 0x11, 0xe1,
#   0x1f, 0x0d, 0xe9, 0x09, 0x01, 0x18, 0xee, 0xe0, 0x18, 0x21, 0x04, 0x0d,
#   0xf7, 0x05, 0x0b, 0x1f, 0xfc, 0xf5, 0x1d, 0x12, 0xf2, 0x02, 0x04, 0xfc,
#   0x14, 0xfb, 0x0b, 0xea, 0x10, 0x04, 0x14, 0x02, 0x19, 0x09, 0x0c, 0x01,
#   0xf4, 0x13, 0x18, 0x1c, 0xf2, 0x0a, 0xe4, 0xfc, 0x00, 0x00, 0x00, 0x00,
#   0x16, 0x7f, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00, 0x00, 0x40, 0x00, 0x00,
#   0xf3, 0xf3, 0xff, 0x0e, 0xea, 0xf2, 0x06, 0xf4, 0xd0, 0xc9, 0xd6, 0xf4,
#   0x06, 0xd5, 0xf6, 0xc0, 0xda, 0xfd, 0xef, 0x0c, 0xf3, 0xde, 0x2a, 0x05,
#   0xf5, 0xe4, 0xf0, 0xff, 0xe8, 0xdb, 0xec, 0xe3, 0x0e, 0xce, 0x11, 0xf4,
#   0x01, 0x0b, 0x1b, 0x02, 0xdd, 0xf9, 0x02, 0x0a, 0xd7, 0xcf, 0xd5, 0xb7,
#   0xef, 0xf4, 0xde, 0xfe, 0xed, 0xed, 0x1b, 0xfd, 0xcf, 0xf8, 0x01, 0xec,
#   0xd1, 0x0e, 0x00, 0x06, 0x16, 0xf1, 0x06, 0xeb, 0x0a, 0xbf, 0xf0, 0xcb,
#   0xed, 0xc6, 0x0a, 0xe6, 0xcc, 0xe1, 0xca, 0xfe, 0xf2, 0xc5, 0xf7, 0xfd,
#   0xc4, 0x28, 0xf5, 0xe9, 0xe5, 0xe6, 0xd7, 0xf7, 0x11, 0x05, 0xc8, 0xeb,
#   0xf4, 0xfa, 0x1c, 0xfc, 0x18, 0x01, 0x24, 0x24, 0xe5, 0xcf, 0xfb, 0xc8,
#   0xe1, 0x07, 0x49, 0x0f, 0x06, 0xdb, 0x1b, 0x16, 0x09, 0xf0, 0xfa, 0xc6,
#   0xce, 0x2d, 0x00, 0xe2, 0xeb, 0x20, 0xe3, 0x04, 0xc1, 0x0d, 0xb8, 0xc5,
#   0xfd, 0xcc, 0xf4, 0xf4, 0xf8, 0xf2, 0x18, 0xf6, 0xdb, 0xf1, 0x0c, 0xd6,
#   0xe7, 0xdc, 0xcf, 0xb3, 0xfa, 0x2b, 0xd9, 0xeb, 0xef, 0xe8, 0xf3, 0x05,
#   0xc8, 0xf7, 0xec, 0x0d, 0x1a, 0x14, 0xf4, 0xee, 0xd5, 0x0b, 0x15, 0xea,
#   0x37, 0xfb, 0x11, 0x10, 0x28, 0xeb, 0xf3, 0xf6, 0xcd, 0xf9, 0xc7, 0xe6,
#   0xc9, 0xe8, 0xcd, 0x15, 0xfd, 0xe8, 0xdc, 0xfb, 0x05, 0x1f, 0xff, 0xfb,
#   0x20, 0x00, 0xe0, 0xd8, 0xeb, 0xf8, 0xd7, 0xd4, 0x27, 0xe6, 0xd2, 0xf6,
#   0x13, 0xe1, 0xef, 0x16, 0xed, 0xec, 0x12, 0x0c, 0xe0, 0x20, 0xfd, 0x10,
#   0x29, 0x0d, 0x2a, 0xe4, 0x15, 0xe0, 0xee, 0xe9, 0x13, 0xc7, 0xe9, 0xe2,
#   0xd3, 0x21, 0x05, 0x14, 0xdd, 0xcc, 0xf6, 0x0c, 0xf6, 0x08, 0xbe, 0x1e,
#   0x04, 0xd9, 0x21, 0xd4, 0x0f, 0x0e, 0xde, 0xf0, 0xc8, 0x0c, 0xe3, 0x01,
#   0x31, 0x09, 0xe6, 0x29, 0x14, 0xf8, 0xa7, 0xca, 0xc1, 0x37, 0x1b, 0xda,
#   0x17, 0xfd, 0x0f, 0xdb, 0x19, 0x1a, 0xfb, 0xd5, 0xf6, 0xef, 0x46, 0xf5,
#   0x18, 0x1f, 0x0e, 0x18, 0x4f, 0xdd, 0x45, 0xf8, 0x2d, 0xa6, 0x22, 0xd5,
#   0xc2, 0xa0, 0x08, 0xf9, 0xf1, 0x2a, 0xd6, 0xc5, 0xe9, 0xba, 0xd1, 0x12,
#   0xa9, 0xed, 0xf3, 0xe1, 0xf0, 0xd0, 0x1c, 0xc9, 0x26, 0x13, 0x33, 0xd9,
#   0xf9, 0xec, 0xea, 0x13, 0x23, 0xd9, 0xfc, 0x0b, 0x26, 0xc2, 0xf5, 0x25,
#   0xd8, 0x04, 0xf6, 0x16, 0xaf, 0x17, 0x1c, 0x47, 0xee, 0xf4, 0xe8, 0x11,
#   0xb5, 0x14, 0xe7, 0x20, 0x06, 0xe1, 0x23, 0x13, 0xf8, 0x04, 0xbb, 0xf4,
#   0xe5, 0x0e, 0x10, 0x14, 0xd0, 0xf6, 0xdb, 0xf2, 0xbe, 0x03, 0x21, 0xeb,
#   0x0a, 0x13, 0x46, 0x02, 0x45, 0x05, 0x2d, 0xef, 0xe4, 0xc3, 0x02, 0x0a,
#   0xde, 0xc5, 0xfa, 0xfc, 0xe6, 0x0b, 0xf4, 0x0a, 0xc5, 0xbc, 0x0c, 0xc7,
#   0x28, 0xff, 0xfa, 0xde, 0x30, 0x4f, 0xe1, 0x02, 0xf1, 0x22, 0x00, 0x1c,
#   0xde, 0xed, 0xe8, 0xe9, 0x04, 0xf6, 0x2f, 0x19, 0xee, 0x0f, 0x17, 0xe4,
#   0x1d, 0x28, 0xe6, 0x09, 0x05, 0x0f, 0x05, 0x0d, 0xf0, 0xd8, 0xd6, 0xfc,
#   0xdb, 0xf3, 0xff, 0xff, 0x0d, 0x2a, 0xe7, 0xfe, 0xe0, 0xa8, 0x13, 0x05,
#   0xf5, 0xf1, 0xeb, 0x0c, 0xf6, 0xdd, 0x1a, 0x0b, 0x21, 0xea, 0x06, 0xf9,
#   0x3d, 0x17, 0xe3, 0xf4, 0x03, 0x04, 0x0e, 0xf7, 0x19, 0xcd, 0xee, 0xcd,
#   0x08, 0x0b, 0xec, 0xd7, 0xf5, 0x1c, 0xd1, 0x0b, 0xdd, 0xd1, 0x1e, 0xc7,
#   0xfd, 0xee, 0xcc, 0xdf, 0xd8, 0x36, 0xf7, 0xfc, 0x16, 0xe4, 0x16, 0xdc,
#   0xe2, 0xd8, 0xfc, 0x18, 0xfc, 0x1e, 0xf1, 0x03, 0xf8, 0xfd, 0xfd, 0xd7,
#   0x0c, 0x17, 0x02, 0xfd, 0xf1, 0x03, 0xe4, 0xf8, 0x0a, 0xd4, 0xac, 0xea,
#   0xed, 0xee, 0xf1, 0xf4, 0x04, 0xde, 0x01, 0x0b, 0x01, 0xf0, 0x10, 0xdf,
#   0x22, 0x15, 0xd5, 0xe6, 0x2a, 0xf2, 0xcf, 0x0d, 0xeb, 0x13, 0x57, 0x09,
#   0xd4, 0x2a, 0xe5, 0x13, 0x05, 0x04, 0x02, 0xdf, 0xfa, 0xf0, 0x31, 0xa1,
#   0x31, 0x25, 0xf3, 0x1c, 0x08, 0x03, 0x10, 0xd2, 0xea, 0xf8, 0x26, 0x1e,
#   0x12, 0xec, 0x2a, 0xd4, 0x00, 0x14, 0x01, 0xf6, 0xe3, 0x2d, 0x24, 0xea,
#   0xc1, 0x33, 0xf7, 0xed, 0xe7, 0x1a, 0xfc, 0x03, 0xd8, 0x15, 0xdf, 0xf2,
#   0x00, 0xee, 0xef, 0x09, 0xd5, 0x20, 0xf5, 0xf7, 0x1e, 0x04, 0xf2, 0x46,
#   0xd5, 0xc9, 0x06, 0xd7, 0xea, 0xf9, 0x11, 0xfc, 0x25, 0x04, 0xfb, 0x04,
#   0x12, 0x2a, 0xfe, 0x00, 0x05, 0x1a, 0xe1, 0x13, 0x0e, 0x04, 0x24, 0xca,
#   0xf2, 0x1d, 0x0f, 0xea, 0xf6, 0x00, 0x14, 0xdc, 0x1d, 0xef, 0x28, 0xdb,
#   0xe6, 0x08, 0x22, 0xe2, 0x01, 0xf5, 0xe0, 0xd9, 0x07, 0xb0, 0x27, 0xe5,
#   0x02, 0x0e, 0xfc, 0x1c, 0x2b, 0x23, 0x03, 0xee, 0xf1, 0xfd, 0xf0, 0x0b,
#   0xea, 0xbe, 0xe6, 0xd4, 0xd6, 0xe4, 0xfd, 0x05, 0xd2, 0x29, 0xef, 0x1b,
#   0xd3, 0xb1, 0x0e, 0xf1, 0xeb, 0xf7, 0xd7, 0xd8, 0xde, 0x38, 0xbd, 0xef,
#   0x2f, 0x33, 0xe8, 0x0f, 0xe9, 0xe1, 0x20, 0xf4, 0x27, 0xcc, 0xdf, 0x0c,
#   0x20, 0xf1, 0xec, 0xe8, 0xff, 0xd9, 0x02, 0xf0, 0xf9, 0xe5, 0xda, 0x23,
#   0x10, 0x1a, 0x0a, 0xfc, 0x0c, 0xfa, 0xf3, 0x20, 0xe0, 0xd6, 0xe9, 0xe7,
#   0x1d, 0x01, 0xf5, 0xf9, 0x0d, 0xdb, 0x06, 0xfb, 0xf2, 0xe9, 0x23, 0xf4,
#   0xf8, 0x0b, 0xf4, 0xf5, 0x1b, 0x08, 0x07, 0xf4, 0x27, 0xfb, 0xf5, 0xf7,
#   0x01, 0x13, 0xef, 0x06, 0x25, 0xfb, 0x22, 0x13, 0xe0, 0xea, 0xed, 0xc9,
#   0xd1, 0xeb, 0xb8, 0xe3, 0xcb, 0xfa, 0xfa, 0xfe, 0x1a, 0xf2, 0xdf, 0x1d,
#   0xde, 0x11, 0xdf, 0xe6, 0xe0, 0xda, 0x1b, 0xeb, 0x08, 0xf2, 0x19, 0xff,
#   0xed, 0x11, 0x14, 0x14, 0xf2, 0x2b, 0xdb, 0x06, 0xe6, 0x0c, 0x0a, 0xdd,
#   0x02, 0x1d, 0x18, 0xfe, 0x1c, 0xf8, 0xd4, 0x0e, 0xf6, 0xb3, 0xca, 0xe2,
#   0xdd, 0xff, 0x3f, 0x34, 0x02, 0x03, 0x19, 0x13, 0xcf, 0xe3, 0x23, 0xe2,
#   0x24, 0x12, 0xca, 0x00, 0xce, 0xf7, 0xe7, 0x1b, 0xc5, 0x00, 0x0e, 0xe7,
#   0x16, 0xf9, 0xf9, 0x36, 0xbf, 0x04, 0x05, 0xc9, 0x12, 0x0a, 0xec, 0x13,
#   0xfa, 0xe3, 0xf8, 0xde, 0xd2, 0x22, 0x03, 0x24, 0xfa, 0x22, 0x1b, 0x12,
#   0xf3, 0x33, 0xf1, 0xe1, 0x0e, 0x29, 0xfb, 0xe0, 0xf4, 0x09, 0x00, 0x24,
#   0xd9, 0xf8, 0xf9, 0x0d, 0xeb, 0x07, 0xdb, 0x05, 0x0a, 0xd0, 0xf5, 0x41,
#   0xd0, 0x0f, 0x26, 0xfc, 0x2e, 0xe1, 0xd6, 0xfa, 0x1b, 0xd6, 0x36, 0xea,
#   0x06, 0x16, 0x37, 0x1d, 0xf3, 0xfc, 0xd4, 0x30, 0x13, 0xfc, 0xc1, 0xfb,
#   0xca, 0xeb, 0x15, 0xef, 0xfc, 0xef, 0x22, 0xe7, 0xce, 0x13, 0xfa, 0xf1,
#   0xa9, 0x09, 0x1e, 0xa4, 0xf7, 0x1b, 0x17, 0xe0, 0xf5, 0xed, 0xf6, 0x03,
#   0x13, 0xeb, 0xfb, 0xe1, 0x2f, 0xbf, 0xe9, 0xf9, 0x16, 0x17, 0x29, 0x0e,
#   0xd3, 0x04, 0xfe, 0xda, 0xbe, 0xf3, 0x12, 0xeb, 0x04, 0x17, 0xeb, 0xd0,
#   0xb8, 0x14, 0x03, 0x00, 0xd8, 0xde, 0x00, 0xc8, 0xe5, 0xce, 0x0f, 0x13,
#   0xe6, 0xfe, 0xc2, 0xf4, 0x1d, 0xea, 0xff, 0x02, 0x14, 0x04, 0x10, 0x14,
#   0x0f, 0x09, 0x25, 0x25, 0xf3, 0xe9, 0x07, 0x0c, 0xe9, 0x31, 0x1d, 0x28,
#   0xf5, 0x25, 0x09, 0x17, 0xec, 0xf5, 0xfe, 0x24, 0xf7, 0x03, 0xed, 0xee,
#   0x9c, 0xc5, 0xc6, 0xfa, 0x17, 0x05, 0xeb, 0xfa, 0xc1, 0x08, 0x1e, 0x05,
#   0x1f, 0xeb, 0x02, 0xc7, 0x09, 0xf7, 0xdb, 0x00, 0x0b, 0xf5, 0x15, 0x1d,
#   0xd2, 0xf2, 0xf2, 0x20, 0xff, 0x05, 0x19, 0x1d, 0xac, 0xfa, 0x31, 0x05,
#   0xcb, 0xbe, 0xff, 0xbd, 0x06, 0xe6, 0x40, 0xc2, 0xf2, 0x11, 0x0d, 0x0a,
#   0xf2, 0x16, 0xf4, 0x07, 0xd4, 0x17, 0xd5, 0x0d, 0xdd, 0x0f, 0xd5, 0x25,
#   0x3a, 0x0f, 0x00, 0xce, 0xfb, 0xf8, 0xdb, 0x0a, 0xe1, 0x08, 0xe3, 0xf5,
#   0x0f, 0x0f, 0x18, 0x23, 0x04, 0xea, 0xe3, 0x2c, 0x10, 0x51, 0xde, 0xe4,
#   0x18, 0x1b, 0xce, 0xfe, 0x0e, 0xf0, 0x08, 0x05, 0x23, 0xed, 0xd6, 0xd9,
#   0x05, 0x26, 0xfc, 0x0e, 0x0c, 0x1d, 0xaf, 0x16, 0x29, 0x2e, 0xe7, 0xfc,
#   0x26, 0x12, 0x09, 0x0a, 0x3a, 0xa0, 0x03, 0x0d, 0xf9, 0xed, 0xf6, 0x03,
#   0x25, 0x0a, 0xb7, 0x00, 0xff, 0xf3, 0xf3, 0xf3, 0xd5, 0xd6, 0x03, 0x04,
#   0x15, 0x06, 0xf6, 0xf4, 0x31, 0x05, 0xee, 0xd1, 0x04, 0x01, 0xf1, 0xec,
#   0x1e, 0x00, 0xe6, 0xbc, 0xe9, 0x0b, 0xef, 0x1e, 0xd7, 0x11, 0x03, 0xf7,
#   0x16, 0x28, 0x03, 0x03, 0xe1, 0xe5, 0x08, 0xe7, 0x0f, 0x01, 0xf8, 0xff,
#   0x0b, 0xda, 0xc0, 0x0f, 0xe7, 0x43, 0xda, 0xfd, 0x25, 0xcf, 0xf0, 0x20,
#   0xfa, 0xda, 0xe9, 0x0d, 0x2c, 0xfb, 0x38, 0xdd, 0xb8, 0xe2, 0xf7, 0xe8,
#   0x0c, 0xf5, 0x2e, 0x02, 0x14, 0xda, 0x0c, 0xee, 0xe1, 0xed, 0xdf, 0xfa,
#   0xde, 0x08, 0x12, 0x1b, 0xea, 0xcb, 0x28, 0xc7, 0x0c, 0xfe, 0xd1, 0xf2,
#   0x1e, 0x19, 0x26, 0xd4, 0x06, 0x1a, 0x4c, 0xf5, 0x02, 0xf2, 0x1a, 0x12,
#   0xd3, 0x2f, 0x01, 0x14, 0x23, 0xc5, 0x1e, 0x08, 0xfa, 0x11, 0xe2, 0x0f,
#   0xff, 0x28, 0x0e, 0x37, 0xe8, 0xfa, 0xd7, 0x02, 0x0b, 0x1c, 0xfa, 0x14,
#   0x28, 0xc8, 0x10, 0x05, 0x27, 0x3b, 0x06, 0x2f, 0xfc, 0x22, 0x12, 0x09,
#   0x00, 0xf4, 0x14, 0x03, 0xe5, 0xf8, 0x04, 0x04, 0xfd, 0x35, 0x0e, 0x09,
#   0x22, 0x24, 0x25, 0xd2, 0x18, 0xd4, 0x28, 0xe8, 0x1f, 0xe1, 0xfa, 0xdf,
#   0xeb, 0xd9, 0x15, 0x0d, 0x03, 0xf8, 0x12, 0x0c, 0x02, 0xf2, 0x1f, 0xdc,
#   0x12, 0x2f, 0xd6, 0x18, 0xf3, 0x09, 0x0e, 0x29, 0xf2, 0xdd, 0x05, 0x16,
#   0xf2, 0x3f, 0x0e, 0xe4, 0xfd, 0x22, 0xfb, 0xcb, 0x18, 0xf4, 0x04, 0x22,
#   0x1d, 0xfd, 0xf1, 0x0e, 0xda, 0x16, 0x05, 0xf2, 0xf1, 0x15, 0xd3, 0x23,
#   0x22, 0x0c, 0x29, 0x12, 0x02, 0x1c, 0xfd, 0xe0, 0x02, 0x45, 0xf0, 0xf2,
#   0x39, 0xfe, 0x27, 0x29, 0x16, 0x17, 0xe8, 0xfa, 0xf8, 0xf1, 0xd5, 0xe9,
#   0xf2, 0x0d, 0xf8, 0x0d, 0x10, 0x1c, 0xc6, 0x01, 0xf0, 0xef, 0x0b, 0x4d,
#   0xe0, 0x03, 0x08, 0xdc, 0x10, 0xf5, 0x0e, 0xee, 0xfc, 0x26, 0xd7, 0x0b,
#   0x29, 0x39, 0x0f, 0x0f, 0x0d, 0xfc, 0xe7, 0xbd, 0xed, 0xfb, 0x0b, 0xe9,
#   0x02, 0x2c, 0xe5, 0xd6, 0x18, 0x04, 0x23, 0xd2, 0xfb, 0xe2, 0x29, 0x17,
#   0xb8, 0xd3, 0xf6, 0x2e, 0xe5, 0xe7, 0xe6, 0xe9, 0x2d, 0xc3, 0xf1, 0xd4,
#   0x07, 0x12, 0xfd, 0x03, 0xef, 0xde, 0x22, 0xf7, 0x1b, 0x02, 0x06, 0xff,
#   0x2d, 0xd5, 0x09, 0xd2, 0xe9, 0xe0, 0x44, 0x22, 0xda, 0x2f, 0x04, 0x0b,
#   0x03, 0x3d, 0xf1, 0xeb, 0xdb, 0xe0, 0xe9, 0x2c, 0x0f, 0xfa, 0xdd, 0xe4,
#   0x1a, 0x18, 0xfe, 0xe1, 0xe4, 0x0b, 0xdf, 0xfc, 0x28, 0xeb, 0xf4, 0x0d,
#   0x06, 0x09, 0x02, 0xd8, 0xfd, 0x15, 0x10, 0xfe, 0x21, 0xe8, 0x2e, 0xf8,
#   0x13, 0x03, 0xf0, 0x2d, 0xe1, 0x06, 0xc0, 0xea, 0xff, 0xf4, 0xe7, 0xde,
#   0xe1, 0x0c, 0xdc, 0xcd, 0x22, 0x0b, 0xe9, 0xf1, 0xfe, 0xe2, 0x02, 0xdc,
#   0xe7, 0xeb, 0x10, 0xec, 0x0a, 0x1e, 0xf1, 0x12, 0x04, 0x3b, 0x0c, 0x1f,
#   0xfb, 0x18, 0x0f, 0x0a, 0x16, 0xff, 0xd4, 0xee, 0x0f, 0x13, 0x0b, 0xde,
#   0xff, 0x0b, 0x15, 0xe9, 0x0d, 0x04, 0x19, 0x27, 0xda, 0xfe, 0x2e, 0x2a,
#   0x0c, 0xfc, 0xca, 0xee, 0x0e, 0xc7, 0xe0, 0xdc, 0x1b, 0xd1, 0xfa, 0xed,
#   0xf5, 0xf6, 0xec, 0xf4, 0x25, 0x0b, 0x0a, 0x16, 0xfb, 0xe8, 0xfc, 0xf5,
#   0xfd, 0xf3, 0xda, 0xb3, 0xf5, 0xe5, 0x0b, 0xfe, 0x2a, 0xd6, 0x03, 0xd8,
#   0x22, 0xdb, 0x08, 0xf9, 0x02, 0xd5, 0xd0, 0xe6, 0x17, 0x18, 0xfa, 0x14,
#   0xd3, 0x03, 0xff, 0x03, 0x1c, 0x02, 0xfc, 0xbd, 0xe9, 0x23, 0xef, 0xee,
#   0xdd, 0xf1, 0xf9, 0xc3, 0x2d, 0x10, 0xe5, 0xed, 0xdd, 0xcc, 0x1e, 0x0c,
#   0xed, 0xd9, 0xd6, 0xfe, 0xfe, 0xee, 0xfb, 0xdb, 0x10, 0xd4, 0xf2, 0xfa,
#   0x04, 0xe0, 0xed, 0x05, 0xcf, 0xff, 0xee, 0xf0, 0x19, 0xf0, 0x23, 0x11,
#   0x08, 0x02, 0xfc, 0x19, 0x03, 0xd7, 0x01, 0xc7, 0xf8, 0xe2, 0xf5, 0xed,
#   0x05, 0xe5, 0xdf, 0xd0, 0xed, 0x2a, 0xd4, 0xf9, 0x1b, 0xdb, 0xfd, 0xe9,
#   0xe7, 0x17, 0x25, 0x0a, 0x0e, 0xee, 0xeb, 0x0d, 0xe5, 0x12, 0xf8, 0xe5,
#   0x10, 0xf4, 0xe0, 0xe0, 0x23, 0xfc, 0x15, 0xee, 0xd3, 0xf9, 0xee, 0xd2,
#   0x07, 0xee, 0xff, 0x1b, 0xf8, 0xfa, 0x14, 0x20, 0xca, 0xcd, 0xda, 0x1f,
#   0x1f, 0xec, 0xef, 0xea, 0x15, 0xf7, 0xd8, 0xd1, 0x1b, 0x0c, 0xf1, 0x11,
#   0xf3, 0x06, 0xf1, 0xd8, 0xee, 0x00, 0xde, 0xec, 0x07, 0x19, 0xec, 0x0b,
#   0xd6, 0x08, 0x11, 0xe1, 0xe7, 0xdf, 0x08, 0xf5, 0xff, 0xf7, 0xdf, 0xd8,
#   0xfb, 0x08, 0xf9, 0x21, 0xbc, 0xf0, 0x0a, 0xf3, 0xea, 0x16, 0xed, 0xe6,
#   0xeb, 0xe5, 0x0c, 0xe5, 0xfb, 0x09, 0xd6, 0x00, 0xcc, 0xda, 0xf5, 0xc0,
#   0xb4, 0x15, 0x0a, 0xf3, 0xe4, 0xff, 0x0d, 0xe1, 0x09, 0xf2, 0xe6, 0xe6,
#   0x07, 0xd8, 0xf3, 0x00, 0xdd, 0xe3, 0xf1, 0xea, 0xd2, 0xdc, 0x2f, 0xe7,
#   0x08, 0xe0, 0xe9, 0x17, 0xfd, 0xcf, 0xd8, 0x07, 0x19, 0x15, 0xe5, 0x1f,
#   0x11, 0x0f, 0x0a, 0xf2, 0xe5, 0xf7, 0xda, 0xd0, 0xff, 0xdc, 0x04, 0xf4,
#   0xf0, 0x0e, 0xe7, 0x17, 0xd3, 0x19, 0xe3, 0xd6, 0x32, 0xeb, 0xec, 0x40,
#   0x2b, 0xd6, 0x43, 0x08, 0xfb, 0x4f, 0xb2, 0x0c, 0xcd, 0x2f, 0x2d, 0xeb,
#   0x00, 0x17, 0x11, 0x37, 0xf8, 0xdf, 0x06, 0x04, 0x38, 0xe2, 0x1e, 0x29,
#   0x38, 0xed, 0xfe, 0xb3, 0x22, 0xd6, 0x14, 0x1c, 0x20, 0xd5, 0x03, 0x0e,
#   0x2d, 0x28, 0xdd, 0x16, 0x17, 0xc9, 0x02, 0x09, 0x08, 0xef, 0xd5, 0x08,
#   0x23, 0x12, 0xf0, 0x34, 0x01, 0x22, 0x02, 0x00, 0xfa, 0xcc, 0xf7, 0xfa,
#   0xf9, 0xf0, 0xe9, 0xe0, 0xfa, 0x02, 0xf1, 0x08, 0x29, 0x46, 0x24, 0xf4,
#   0x04, 0xea, 0x36, 0x10, 0x0d, 0xff, 0x0c, 0x1a, 0xda, 0xcb, 0xf1, 0x38,
#   0xd7, 0xee, 0xf1, 0xf0, 0x37, 0x1f, 0xc5, 0x29, 0x27, 0x17, 0xda, 0x24,
#   0x27, 0x2e, 0x14, 0xf6, 0x11, 0x0d, 0xc3, 0x1d, 0xf6, 0xbd, 0xf5, 0xd3,
#   0x04, 0xfd, 0xee, 0xf0, 0xd7, 0xe2, 0xee, 0xe8, 0xb8, 0xc4, 0xeb, 0x14,
#   0x30, 0xd3, 0xe1, 0xff, 0xd8, 0x03, 0x07, 0xe7, 0xe4, 0x26, 0xd9, 0x28,
#   0xe2, 0x09, 0xf4, 0x0c, 0x15, 0x23, 0x0c, 0xf4, 0xcc, 0xf5, 0x21, 0xd9,
#   0x15, 0xf3, 0xe4, 0x0e, 0x06, 0x0a, 0x09, 0xfb, 0xe0, 0xd4, 0x0f, 0x04,
#   0x2f, 0xf8, 0xf9, 0xe4, 0xf0, 0x23, 0x05, 0x03, 0xd4, 0xec, 0x09, 0xec,
#   0x0f, 0x22, 0x0d, 0x16, 0x24, 0xc2, 0x0e, 0xe4, 0xff, 0xda, 0x08, 0xea,
#   0x1a, 0xff, 0xdd, 0x25, 0xe6, 0xdd, 0xd9, 0x29, 0xdf, 0x02, 0x22, 0x08,
#   0x1f, 0xc4, 0x0f, 0x16, 0x08, 0xf6, 0xe5, 0x22, 0xf7, 0xd9, 0xea, 0x07,
#   0xf4, 0xfe, 0xd8, 0xfa, 0x10, 0xff, 0xc8, 0xfa, 0x15, 0xf1, 0x07, 0x01,
#   0xe7, 0xe8, 0x41, 0x0d, 0xf8, 0x0c, 0xf7, 0xf6, 0xd7, 0xf5, 0xdc, 0xbf,
#   0xd2, 0x1e, 0xea, 0x20, 0x04, 0x0b, 0xed, 0x22, 0xca, 0xfa, 0xeb, 0x07,
#   0xf3, 0xbb, 0xff, 0xde, 0x06, 0xdc, 0x0e, 0x05, 0xd7, 0xcc, 0x1c, 0x00,
#   0x26, 0xe7, 0xfe, 0x03, 0x30, 0xff, 0xcb, 0x04, 0xf7, 0x01, 0x1f, 0xd6,
#   0xe8, 0x0d, 0x0e, 0x04, 0xf1, 0x0a, 0xe7, 0xe8, 0xd8, 0xf8, 0x15, 0xdd,
#   0xd3, 0x1b, 0x10, 0x08, 0x0a, 0xf2, 0xfb, 0xee, 0xc1, 0xf8, 0x16, 0xcb,
#   0x06, 0xc7, 0xf0, 0xc6, 0xfe, 0x0d, 0xb2, 0x0b, 0xd0, 0xea, 0xef, 0xd8,
#   0xef, 0xbd, 0xcf, 0xff, 0x9e, 0x31, 0x03, 0x27, 0xe5, 0x1b, 0xf3, 0xe5,
#   0x0f, 0xfa, 0xf6, 0xd8, 0xf9, 0x18, 0xe1, 0xdd, 0xdb, 0x0c, 0xd2, 0xf0,
#   0xb5, 0xfd, 0x2e, 0xe1, 0x1d, 0xec, 0x06, 0xc1, 0x14, 0xf0, 0x04, 0xe8,
#   0x0e, 0xfa, 0x0e, 0x0c, 0x1c, 0xfc, 0xd5, 0xcd, 0x16, 0xd6, 0xb0, 0xc3,
#   0x0d, 0x31, 0xdb, 0xd3, 0xd3, 0x0f, 0xe3, 0xc8, 0xf8, 0x11, 0x03, 0xdf,
#   0x03, 0xf4, 0xcf, 0xd7, 0x03, 0xd8, 0xd6, 0xc0, 0x0c, 0xb3, 0x08, 0xde,
#   0xd8, 0x1f, 0x06, 0x09, 0xff, 0x1a, 0xe0, 0xcd, 0xeb, 0x35, 0xee, 0x07,
#   0x04, 0x19, 0xfe, 0x27, 0xde, 0xf8, 0xcc, 0x01, 0x01, 0x21, 0x0c, 0x15,
#   0xde, 0x2d, 0xfe, 0x01, 0xe1, 0xd5, 0x31, 0x1a, 0x0e, 0xec, 0x26, 0xff,
#   0xfe, 0x01, 0x00, 0x16, 0x0d, 0x2a, 0xff, 0xe7, 0x26, 0xcd, 0x1b, 0x0d,
#   0xe8, 0xfc, 0xfe, 0xee, 0x02, 0x15, 0x05, 0xd1, 0xfb, 0xf6, 0x27, 0x00,
#   0xe2, 0x1d, 0xdf, 0x1e, 0xfe, 0xcd, 0xb4, 0xd6, 0xed, 0x0d, 0xef, 0x08,
#   0xf2, 0x01, 0xe7, 0xf7, 0x0e, 0x0e, 0xe8, 0x3e, 0xe2, 0xd3, 0x1d, 0x05,
#   0x12, 0xcb, 0x13, 0x03, 0xcd, 0x26, 0xc6, 0xdd, 0x01, 0x1e, 0x0c, 0xd5,
#   0x15, 0xf1, 0xdb, 0x19, 0x27, 0xdd, 0x14, 0xf5, 0xea, 0xfc, 0xfc, 0xde,
#   0xd6, 0x02, 0x19, 0xa8, 0x0b, 0xde, 0x09, 0xdb, 0xf1, 0xe8, 0xd5, 0x1e,
#   0x21, 0xd1, 0xf9, 0xf9, 0x11, 0xee, 0xcd, 0xce, 0x12, 0xf3, 0x07, 0xf7,
#   0x1e, 0xeb, 0xef, 0x0e, 0x09, 0xd3, 0xca, 0x0f, 0x14, 0x1b, 0x00, 0x11,
#   0xda, 0xf6, 0xfc, 0x0a, 0xf8, 0x3a, 0xfa, 0xd9, 0x16, 0x15, 0xfd, 0x01,
#   0xe2, 0xfc, 0xdf, 0x18, 0x10, 0x1e, 0xe5, 0x31, 0x29, 0xf6, 0x1f, 0x27,
#   0xe9, 0xba, 0x06, 0x13, 0x09, 0x15, 0xfc, 0x18, 0x27, 0x04, 0xea, 0xf3,
#   0xdb, 0xd2, 0xf3, 0xfb, 0x32, 0xc5, 0xea, 0xdc, 0xf2, 0xf4, 0x28, 0x14,
#   0xe9, 0x07, 0xed, 0xd2, 0x02, 0xfd, 0xf6, 0x0d, 0x09, 0x27, 0xec, 0xc8,
#   0xee, 0x96, 0xe9, 0xdc, 0xf0, 0xef, 0x0b, 0xf1, 0xf4, 0x25, 0xdb, 0xea,
#   0xf2, 0xeb, 0xf3, 0xf1, 0xd4, 0xbc, 0xed, 0xf9, 0xf9, 0xd0, 0x0e, 0xe5,
#   0xee, 0xfa, 0xf0, 0x19, 0xe0, 0xfa, 0xe8, 0xd3, 0x14, 0xc2, 0xf1, 0x13,
#   0xbc, 0xf2, 0xbf, 0xed, 0x1f, 0x03, 0x3e, 0xe9, 0xdd, 0x09, 0xd9, 0xf7,
#   0x05, 0x12, 0xfb, 0x0d, 0x3a, 0xff, 0xd9, 0x35, 0x02, 0xe3, 0x0d, 0xb0,
#   0xc3, 0x09, 0xee, 0xee, 0xe7, 0x08, 0x37, 0xf5, 0x06, 0xde, 0x0b, 0x10,
#   0x0d, 0xec, 0x03, 0x15, 0x19, 0xe8, 0xfe, 0xfb, 0xfb, 0x0a, 0x47, 0xf9,
#   0xff, 0xea, 0x08, 0x0c, 0xb6, 0xde, 0x1d, 0xff, 0x29, 0x20, 0xdf, 0xfc,
#   0xe3, 0xd5, 0xe3, 0x13, 0xc5, 0xb6, 0x1d, 0xf6, 0xe7, 0xdc, 0x0b, 0xe2,
#   0xe9, 0xe0, 0x32, 0x41, 0xff, 0xf3, 0xf2, 0xf3, 0xf4, 0x06, 0x05, 0x08,
#   0x03, 0xdc, 0xfb, 0x1f, 0x4c, 0xe4, 0xff, 0xf5, 0xb7, 0x48, 0xfd, 0x02,
#   0xe5, 0x19, 0xe1, 0xb6, 0xc7, 0xe8, 0x2f, 0x20, 0xe3, 0xfc, 0x02, 0xea,
#   0xe2, 0xe5, 0xe3, 0xf0, 0x05, 0xf9, 0xe4, 0xfd, 0xb8, 0x26, 0x44, 0x11,
#   0x1f, 0xf5, 0x20, 0xd8, 0x0d, 0x06, 0x55, 0xd9, 0x2f, 0xcf, 0xdf, 0xfd,
#   0xee, 0xc1, 0x06, 0xee, 0x36, 0xe2, 0xf7, 0x18, 0x19, 0x11, 0xd1, 0xf9,
#   0xdb, 0xc3, 0xe1, 0xb9, 0xe0, 0x04, 0xd9, 0xf7, 0xeb, 0xda, 0xfd, 0x22,
#   0xd0, 0xf6, 0x0b, 0x32, 0xdc, 0x0c, 0xc5, 0x43, 0xf4, 0x14, 0xcb, 0xfc,
#   0xf7, 0xf6, 0x07, 0xbd, 0xda, 0xf6, 0xc0, 0x0d, 0xe1, 0x0b, 0x04, 0x1b,
#   0xfa, 0x0c, 0x0a, 0xff, 0xe5, 0x14, 0x06, 0x35, 0x04, 0x00, 0x0c, 0xf8,
#   0xf1, 0x01, 0x09, 0xd8, 0x11, 0xdd, 0xd9, 0xfd, 0x18, 0x1f, 0x09, 0xdd,
#   0x0e, 0xda, 0xdd, 0xfe, 0xd1, 0xd3, 0xd8, 0xcc, 0x03, 0x11, 0xe5, 0xe2,
#   0xf1, 0xfa, 0xfb, 0xfb, 0x15, 0x06, 0xe5, 0x1a, 0xf6, 0x17, 0x46, 0x15,
#   0xf7, 0x0f, 0xa8, 0x0a, 0x1d, 0x23, 0xff, 0xb8, 0xde, 0x18, 0xf9, 0x2d,
#   0xef, 0x26, 0xfb, 0xf3, 0x2f, 0xf5, 0xe3, 0x01, 0xfa, 0x20, 0xc5, 0xf3,
#   0x0b, 0xf5, 0xc7, 0xea, 0x23, 0xf8, 0x19, 0x1c, 0xd9, 0x11, 0xfc, 0x0e,
#   0xdf, 0xed, 0xf0, 0xfa, 0x04, 0xe3, 0x0a, 0xdd, 0x23, 0xc6, 0xc9, 0x0e,
#   0xcb, 0xea, 0xf2, 0x02, 0x21, 0xdf, 0xe8, 0x2a, 0x02, 0xfa, 0x08, 0x15,
#   0xeb, 0xd6, 0xe7, 0xda, 0xe2, 0x1b, 0x08, 0xe5, 0xd6, 0x21, 0xfb, 0xc9,
#   0xfe, 0x01, 0xf5, 0xf3, 0xd2, 0x13, 0x1d, 0xd3, 0x17, 0x43, 0xcf, 0xca,
#   0xcd, 0x15, 0xf8, 0x0a, 0xf8, 0xed, 0x41, 0xdb, 0x21, 0x10, 0xca, 0x28,
#   0xd9, 0x1f, 0x11, 0xd6, 0x1a, 0x08, 0xc1, 0xf1, 0xc9, 0xeb, 0xf6, 0x0e,
#   0xb8, 0x10, 0x0b, 0xe7, 0xec, 0xc3, 0xbb, 0xde, 0xf3, 0xd4, 0xee, 0xc3,
#   0x10, 0x07, 0xd2, 0x12, 0xfe, 0xe4, 0x08, 0x02, 0x01, 0x0a, 0x13, 0x17,
#   0x0b, 0xef, 0xea, 0xfa, 0x2b, 0xfa, 0xff, 0x14, 0xe2, 0x45, 0xf9, 0xf4,
#   0xdd, 0xde, 0xdf, 0xc2, 0xd4, 0x4b, 0x25, 0x24, 0xf8, 0x07, 0x09, 0xf6,
#   0xd9, 0x22, 0x02, 0xdd, 0x1a, 0xfd, 0x29, 0xf9, 0xde, 0xe7, 0xed, 0x01,
#   0x22, 0xf3, 0x08, 0x10, 0x3c, 0x1b, 0x06, 0x33, 0x19, 0x08, 0xd5, 0xd9,
#   0xd7, 0xe4, 0xcc, 0xf2, 0x0b, 0xe1, 0xfa, 0xe2, 0xcf, 0xf2, 0xf9, 0xd2,
#   0xff, 0xff, 0x1a, 0xdd, 0x03, 0xf6, 0xd5, 0x15, 0xe1, 0xdc, 0xe0, 0xec,
#   0xf9, 0xbc, 0x2a, 0xdc, 0xe6, 0xc0, 0xe8, 0x0d, 0xfe, 0x00, 0x01, 0x06,
#   0xc7, 0x03, 0x0f, 0xf0, 0x20, 0xef, 0xfb, 0xeb, 0xd9, 0xdb, 0xf0, 0xd3,
#   0xfe, 0xec, 0x20, 0x33, 0xe9, 0x02, 0xeb, 0xcf, 0xfb, 0xfb, 0xf0, 0xe6,
#   0xea, 0xed, 0x02, 0x11, 0x2b, 0xed, 0x28, 0xb5, 0xfe, 0xdf, 0x29, 0xec,
#   0xfd, 0xfb, 0xeb, 0x01, 0xdb, 0xf3, 0x18, 0x0c, 0xf3, 0xe3, 0xc1, 0xd0,
#   0x08, 0x24, 0x0e, 0xf4, 0xbd, 0x03, 0x04, 0xf6, 0xea, 0x23, 0xd9, 0xfb,
#   0x04, 0x32, 0xf9, 0x13, 0xfd, 0xfb, 0xcd, 0xc2, 0x14, 0xe3, 0x04, 0x1f,
#   0x05, 0x0e, 0x3c, 0x06, 0xf2, 0xdc, 0xf8, 0xcf, 0xd0, 0xe7, 0xdb, 0xfd,
#   0xe3, 0xde, 0xdc, 0xd0, 0xdb, 0x0e, 0xb9, 0xf0, 0xf4, 0x21, 0x17, 0x0b,
#   0x10, 0xd7, 0x00, 0x0a, 0xd6, 0xf6, 0x03, 0xc5, 0xf4, 0xeb, 0xfd, 0xd2,
#   0x18, 0xe0, 0xfd, 0xf3, 0x11, 0x0c, 0x15, 0xe7, 0xec, 0xfb, 0xdf, 0x01,
#   0xed, 0xee, 0xee, 0x0c, 0x04, 0x1b, 0x02, 0x02, 0xfb, 0xe2, 0xd3, 0xff,
#   0xec, 0x03, 0xf1, 0x09, 0x1c, 0xda, 0x0e, 0xf6, 0xd7, 0xff, 0x2b, 0xff,
#   0xcc, 0xe8, 0xd8, 0xe1, 0xf2, 0xd7, 0xdd, 0x08, 0x0e, 0xdc, 0xdc, 0x15,
#   0xea, 0xdc, 0xe1, 0xf6, 0xe0, 0xf6, 0xf9, 0xdb, 0xcd, 0x0f, 0x12, 0xd0,
#   0x0c, 0xf5, 0xe6, 0x16, 0xfb, 0xe9, 0x01, 0xf3, 0x0c, 0x19, 0xdc, 0x2c,
#   0x06, 0xf3, 0xee, 0x14, 0xeb, 0xde, 0xd7, 0x06, 0x06, 0x07, 0xe5, 0xdc,
#   0x06, 0xf9, 0xf7, 0xf4, 0xd9, 0xdf, 0xf2, 0xd8, 0xe8, 0xfe, 0x1c, 0x1a,
#   0xf6, 0xf9, 0xce, 0xed, 0xf1, 0xde, 0xf7, 0xe5, 0x01, 0xeb, 0xf8, 0x0a,
#   0xee, 0xe0, 0x0a, 0x23, 0x0c, 0xf2, 0x15, 0x04, 0x04, 0xc9, 0xe1, 0x0a,
#   0xf4, 0x00, 0x3c, 0xc7, 0xea, 0x34, 0xf1, 0x18, 0x00, 0x13, 0x36, 0xea,
#   0x03, 0xf6, 0xe5, 0xfc, 0x2e, 0x15, 0xdb, 0x03, 0x00, 0x26, 0xe9, 0xf5,
#   0xef, 0xc1, 0xfc, 0x35, 0x0f, 0x14, 0xe1, 0xca, 0xf0, 0xf6, 0xd6, 0xf7,
#   0xf0, 0xca, 0xde, 0xd8, 0x3b, 0xbd, 0xf4, 0x16, 0xcd, 0x2b, 0x22, 0xfa,
#   0xcb, 0x19, 0xe4, 0xfc, 0x18, 0x06, 0x0a, 0xeb, 0xd2, 0x11, 0x04, 0xce,
#   0xce, 0xdd, 0xe5, 0x0f, 0xdf, 0x08, 0xf7, 0xd9, 0xf5, 0x03, 0xf3, 0x1d,
#   0xe5, 0x02, 0xec, 0x0d, 0xcf, 0x13, 0x07, 0x01, 0xdc, 0x07, 0x0b, 0xd5,
#   0x21, 0xff, 0xfc, 0x05, 0x0a, 0x21, 0xe7, 0xe2, 0xf8, 0xe0, 0xb7, 0x14,
#   0xd0, 0xca, 0xf9, 0x0a, 0xfd, 0xec, 0xe9, 0xf1, 0x04, 0xec, 0xe2, 0xb0,
#   0x24, 0x03, 0x16, 0x16, 0xfe, 0x2e, 0xcd, 0xef, 0xfc, 0xee, 0xbe, 0xaa,
#   0xe1, 0x4a, 0xfe, 0xeb, 0x2b, 0xee, 0x07, 0x08, 0x0a, 0x22, 0xf3, 0xf4,
#   0x05, 0xcd, 0xe6, 0x01, 0x1e, 0xe5, 0xf2, 0x29, 0x21, 0xf4, 0x1b, 0x18,
#   0xf3, 0x19, 0xeb, 0x1e, 0xd7, 0x03, 0xeb, 0xf0, 0xe2, 0x15, 0x02, 0xee,
#   0x02, 0xbe, 0x03, 0xe2, 0xce, 0xe2, 0xef, 0xed, 0xee, 0xc7, 0x0f, 0x01,
#   0xdb, 0x2c, 0x3e, 0xe3, 0x28, 0xef, 0xf1, 0x2e, 0xff, 0xf6, 0x08, 0xe8,
#   0xde, 0xee, 0xfd, 0x26, 0xfb, 0xd8, 0x24, 0x11, 0xdf, 0xf0, 0xf4, 0xf6,
#   0x11, 0x06, 0x10, 0xe7, 0x20, 0x19, 0xf8, 0x06, 0xea, 0x14, 0xf7, 0xf9,
#   0xb3, 0x9f, 0xc4, 0xf3, 0x03, 0xe8, 0xd7, 0x08, 0xfa, 0x32, 0x27, 0xec,
#   0x2b, 0xff, 0x16, 0x06, 0x05, 0xeb, 0xcc, 0x0a, 0x22, 0xf8, 0x1c, 0x03,
#   0xfd, 0xdf, 0xf2, 0x1b, 0x17, 0xcf, 0x0e, 0xed, 0xb7, 0x08, 0x20, 0x00,
#   0xe7, 0xb2, 0x19, 0xdf, 0xf1, 0x04, 0xfe, 0xf3, 0x26, 0x07, 0x11, 0xff,
#   0x03, 0xd9, 0x0c, 0xff, 0xdc, 0x11, 0x2d, 0x14, 0xea, 0xf5, 0xe7, 0xd3,
#   0x10, 0x19, 0xf5, 0xda, 0x1d, 0xf3, 0xf2, 0xec, 0xf5, 0xf5, 0x24, 0x02,
#   0x24, 0x15, 0xfd, 0xed, 0xd3, 0x17, 0xfa, 0x11, 0x03, 0x15, 0xea, 0xf6,
#   0xf0, 0x04, 0xf1, 0x1a, 0x10, 0x23, 0xe5, 0xec, 0x1c, 0x12, 0xd7, 0x01,
#   0xcf, 0x19, 0xe3, 0x12, 0xe4, 0xf4, 0xd7, 0xd2, 0xef, 0x1e, 0xf9, 0xcc,
#   0x09, 0x0e, 0xf9, 0x00, 0xe2, 0xf7, 0xc2, 0xec, 0xca, 0x21, 0x0e, 0xfd,
#   0x11, 0x00, 0x00, 0xf0, 0xf1, 0xd1, 0xce, 0xb1, 0xf4, 0x10, 0x24, 0x17,
#   0xe1, 0xe7, 0x0c, 0xdb, 0x0d, 0xe9, 0xf5, 0xd7, 0x0b, 0xf2, 0xfe, 0xe0,
#   0x22, 0xf7, 0x05, 0x09, 0xd1, 0xe6, 0x1e, 0xdd, 0x2b, 0x02, 0x0e, 0x04,
#   0x1b, 0xfd, 0xcf, 0xc0, 0x3a, 0xdf, 0xfc, 0x18, 0xbd, 0xfd, 0x01, 0x16,
#   0x08, 0x0f, 0x05, 0x1d, 0x0d, 0x06, 0xc9, 0xf8, 0xd9, 0x09, 0xef, 0x0d,
#   0xc6, 0xf0, 0xfc, 0x19, 0xf4, 0xe4, 0xf0, 0x1c, 0x21, 0xf5, 0xf4, 0x09,
#   0x04, 0x0b, 0x1c, 0xdd, 0x00, 0x13, 0xf3, 0x2b, 0xe7, 0x1d, 0xee, 0xef,
#   0xdc, 0x20, 0xe9, 0x34, 0x01, 0x0a, 0x21, 0xc4, 0xf5, 0x16, 0xd7, 0x12,
#   0x2a, 0xdb, 0x14, 0xf7, 0x40, 0xe4, 0xe4, 0xdc, 0xb1, 0xdf, 0xee, 0x0c,
#   0x1b, 0x10, 0xeb, 0xcb, 0xe9, 0x28, 0xd3, 0xdf, 0x00, 0xf1, 0x13, 0xef,
#   0xfd, 0xc1, 0xe9, 0x20, 0xf5, 0xf5, 0x0d, 0xe9, 0xd8, 0xf6, 0xf9, 0x07,
#   0xfd, 0xe0, 0x0e, 0xc9, 0xfa, 0x18, 0xbd, 0x09, 0x27, 0x0b, 0x00, 0xfa,
#   0xf1, 0xe4, 0x05, 0xf5, 0xeb, 0x1a, 0xec, 0xf8, 0xe6, 0xf7, 0xfb, 0x26,
#   0xd8, 0xf4, 0x27, 0x04, 0x21, 0x1f, 0xec, 0x06, 0xf3, 0x16, 0xdb, 0xc3,
#   0x21, 0xfe, 0x10, 0xf6, 0x15, 0xff, 0xff, 0xe9, 0xf4, 0x00, 0x10, 0xf2,
#   0xff, 0xef, 0xca, 0xef, 0xb0, 0xc2, 0xe6, 0xec, 0xd0, 0xe9, 0xcc, 0xf5,
#   0xfc, 0x1b, 0xf8, 0xf8, 0x21, 0x04, 0xfc, 0xf6, 0x0a, 0x0a, 0x0a, 0x15,
#   0xef, 0x0b, 0x19, 0xf7, 0xb9, 0xea, 0x0d, 0xf5, 0x06, 0x07, 0xea, 0xf3,
#   0xf0, 0x2a, 0xdc, 0xde, 0xfa, 0xb1, 0xf0, 0xdb, 0x00, 0xea, 0x0a, 0xf7,
#   0xf9, 0xbc, 0x27, 0x39, 0x19, 0x2e, 0x12, 0xfc, 0xf9, 0xec, 0xf5, 0xfd,
#   0xf9, 0x19, 0xe8, 0xf8, 0x08, 0xee, 0xea, 0x24, 0x02, 0xd7, 0x09, 0x0f,
#   0xd8, 0xc8, 0xdf, 0xee, 0x01, 0x17, 0xfa, 0xe9, 0xcc, 0x25, 0xd1, 0xf8,
#   0xdb, 0x06, 0x1f, 0xf8, 0x05, 0x15, 0xe3, 0x0a, 0xce, 0xf7, 0x05, 0x05,
#   0xee, 0x15, 0xe9, 0xca, 0x25, 0xc4, 0xd3, 0xe2, 0x13, 0x0e, 0xd3, 0xde,
#   0xdd, 0xd5, 0x16, 0xf1, 0xea, 0xf9, 0x0d, 0x00, 0x1a, 0xf6, 0x03, 0xfa,
#   0x10, 0x14, 0x19, 0x0e, 0xd0, 0x1d, 0xd7, 0x30, 0x1e, 0xcf, 0xe9, 0x1e,
#   0xf7, 0xe7, 0xe7, 0x05, 0xd9, 0xcd, 0x21, 0x33, 0xf7, 0x1b, 0xb7, 0xe2,
#   0xfe, 0xef, 0xdc, 0xf8, 0xd7, 0xf6, 0xe2, 0x1b, 0xe8, 0xf3, 0xf6, 0xff,
#   0xfe, 0x3c, 0xe0, 0xf5, 0xfc, 0xd4, 0x2a, 0x2c, 0xf9, 0x24, 0xf5, 0x0f,
#   0x28, 0x2d, 0x11, 0x01, 0xd1, 0xc7, 0xfd, 0x0a, 0x0b, 0xd4, 0x14, 0x23,
#   0xbc, 0xe1, 0x17, 0xff, 0xeb, 0x1d, 0xf7, 0xe9, 0xef, 0x14, 0x08, 0xdc,
#   0xd1, 0x20, 0xd5, 0xd6, 0x35, 0x0b, 0xf9, 0xa2, 0xfd, 0xf1, 0x4d, 0x13,
#   0xd3, 0x10, 0x16, 0xf8, 0xea, 0x2a, 0x01, 0xcf, 0xea, 0x07, 0x10, 0x27,
#   0xda, 0x2b, 0x05, 0xd9, 0x2b, 0xd0, 0xf4, 0xdd, 0xeb, 0xda, 0xbe, 0xe9,
#   0xe7, 0xe0, 0xc2, 0x18, 0xe4, 0xd6, 0xf3, 0xe9, 0xf4, 0x1b, 0xef, 0x00,
#   0xcc, 0x15, 0xd7, 0x10, 0xfd, 0xfc, 0x0c, 0x10, 0x1c, 0x2a, 0xf6, 0x06,
#   0xe6, 0xfa, 0xf7, 0xe0, 0xf6, 0x37, 0xf9, 0x07, 0xdc, 0xfd, 0x1e, 0x03,
#   0x1e, 0xe3, 0xf1, 0xb6, 0xe9, 0xe1, 0x02, 0x25, 0x09, 0xb3, 0x37, 0x2a,
#   0x25, 0x1a, 0x25, 0xe4, 0x06, 0xd3, 0xd7, 0x00, 0x1e, 0xe7, 0x2d, 0x04,
#   0x06, 0x27, 0x14, 0xff, 0xd6, 0xb2, 0x3a, 0xdc, 0xfe, 0xdd, 0xc7, 0xe5,
#   0x17, 0xb0, 0xd5, 0xfa, 0xe1, 0x31, 0x3c, 0xc1, 0x17, 0xbe, 0x0f, 0x3c,
#   0x22, 0xf6, 0x01, 0x07, 0xec, 0xf0, 0x24, 0xe3, 0xce, 0x04, 0x0b, 0xf3,
#   0xe9, 0x50, 0xe7, 0xc1, 0x00, 0x2f, 0xb8, 0xf0, 0x13, 0xd7, 0xd6, 0x26,
#   0xf8, 0x04, 0x09, 0x16, 0xeb, 0xb1, 0xcf, 0x01, 0xdf, 0x0f, 0xf6, 0x06,
#   0x18, 0x14, 0x0d, 0x10, 0xc3, 0xea, 0xce, 0x0a, 0xfc, 0x2e, 0x12, 0xf6,
#   0x23, 0x30, 0x15, 0xdc, 0xe2, 0xd8, 0x21, 0xea, 0x0b, 0x06, 0xbb, 0xed,
#   0xc9, 0xea, 0xef, 0x29, 0xfc, 0xd4, 0xe2, 0xe8, 0x1a, 0xf1, 0x09, 0xd7,
#   0x10, 0x1a, 0x16, 0xc8, 0x24, 0xf3, 0x16, 0x07, 0x0a, 0x16, 0xcf, 0xfc,
#   0x1f, 0xeb, 0xab, 0x2a, 0x0c, 0xd7, 0x1b, 0x32, 0x1d, 0x04, 0xcf, 0x2c,
#   0xec, 0x19, 0xce, 0x03, 0xe2, 0x07, 0x11, 0x14, 0xf8, 0x01, 0x10, 0xe4,
#   0x0d, 0xd7, 0x18, 0xef, 0x07, 0xda, 0xd9, 0xf6, 0xe6, 0xa4, 0x0e, 0xf6,
#   0xf6, 0x13, 0xc9, 0x17, 0x04, 0x07, 0xfa, 0x31, 0x21, 0xf3, 0x00, 0x33,
#   0xe3, 0xfa, 0xee, 0xed, 0x22, 0xf8, 0xec, 0xff, 0x29, 0xf2, 0x39, 0xe8,
#   0xf1, 0x38, 0xee, 0xef, 0x0a, 0x06, 0xc1, 0x0e, 0x1a, 0xdd, 0x00, 0x21,
#   0xfa, 0xc9, 0xd5, 0xfd, 0xcc, 0xf4, 0x2a, 0x03, 0xfe, 0x09, 0xf4, 0x07,
#   0xfe, 0xde, 0x01, 0x00, 0x30, 0x32, 0xca, 0xf2, 0x1b, 0xe0, 0xc1, 0xb0,
#   0xf0, 0xdc, 0x12, 0x0c, 0x1c, 0x03, 0xff, 0xf6, 0xfb, 0xf3, 0x3c, 0x14,
#   0x32, 0x02, 0x0b, 0xce, 0xd9, 0x41, 0xe8, 0xf4, 0xc3, 0xf7, 0xe3, 0xd9,
#   0xec, 0x1e, 0x06, 0xfd, 0xfb, 0xe0, 0xf3, 0x0b, 0x11, 0xfc, 0xea, 0x2a,
#   0x08, 0xda, 0xdc, 0xf6, 0xe9, 0xe5, 0x1a, 0x09, 0xb5, 0xde, 0x22, 0x04,
#   0xc3, 0xcf, 0x28, 0x01, 0xf8, 0xfc, 0xe8, 0x03, 0xf1, 0xf9, 0xff, 0x2a,
#   0xe1, 0xbc, 0x1a, 0xd4, 0xfc, 0xd5, 0x0e, 0x29, 0xda, 0x01, 0xdb, 0x0b,
#   0x0c, 0xe9, 0x0d, 0xfb, 0xd5, 0xef, 0x0a, 0x10, 0x21, 0xff, 0x1e, 0x0a,
#   0x24, 0xe3, 0xff, 0x39, 0xed, 0xf0, 0x18, 0xf2, 0x1f, 0x09, 0x19, 0x15,
#   0xd4, 0x00, 0xfe, 0x06, 0x17, 0xdd, 0xed, 0xdc, 0xbf, 0xd5, 0xc2, 0xd5,
#   0xe8, 0xd8, 0xe6, 0x25, 0xe5, 0x12, 0x18, 0x02, 0x0f, 0x09, 0xfb, 0xde,
#   0x06, 0xdc, 0x2a, 0x00, 0x1c, 0xe2, 0x1b, 0x0a, 0xc4, 0xed, 0xf5, 0x0e,
#   0xee, 0x21, 0x10, 0xf7, 0xa4, 0xf8, 0x2c, 0x0c, 0xe8, 0xd6, 0xd3, 0xe6,
#   0x31, 0x1d, 0x26, 0x35, 0x0b, 0xc6, 0xf8, 0xe3, 0xda, 0x19, 0xf0, 0xf8,
#   0xc8, 0xd1, 0x08, 0x09, 0xfe, 0x22, 0xff, 0x19, 0x15, 0x12, 0x0d, 0xff,
#   0xdd, 0x17, 0xcd, 0x26, 0xca, 0x32, 0xfb, 0x20, 0xe9, 0xe8, 0x00, 0xfd,
#   0xf2, 0xd7, 0x1b, 0xd9, 0x23, 0x41, 0xf7, 0x03, 0xf2, 0xce, 0x0b, 0x06,
#   0x34, 0xe0, 0x04, 0x1a, 0xe1, 0xdf, 0xdd, 0x15, 0xf7, 0x20, 0xf1, 0x10,
#   0x05, 0xe5, 0x0d, 0xc7, 0x00, 0xf6, 0x07, 0x06, 0x1d, 0x20, 0xed, 0xf7,
#   0xf8, 0x9f, 0xee, 0xda, 0x0c, 0xe8, 0x3b, 0x13, 0x15, 0x03, 0xfb, 0xda,
#   0xe6, 0x2f, 0xd5, 0xc7, 0xc7, 0x12, 0xb4, 0xdb, 0x22, 0x15, 0x1b, 0xfd,
#   0xd0, 0x0c, 0x07, 0x14, 0x04, 0xed, 0xf3, 0xdb, 0x10, 0xd3, 0xe1, 0x09,
#   0xfb, 0x18, 0xa7, 0x0b, 0xef, 0xe2, 0x2c, 0x18, 0x05, 0x19, 0xef, 0xfc,
#   0x1e, 0xec, 0xee, 0xe7, 0x52, 0xfa, 0xea, 0xfb, 0xf0, 0x0d, 0x1c, 0xf0,
#   0x00, 0x09, 0xd2, 0x15, 0x04, 0xea, 0x35, 0xf9, 0xf4, 0xf3, 0x2d, 0x0e,
#   0x22, 0x12, 0xc2, 0xf3, 0xcd, 0x0d, 0xfa, 0x30, 0x21, 0xf0, 0x00, 0x17,
#   0x00, 0xf0, 0x13, 0x05, 0x17, 0x02, 0xeb, 0xdd, 0xf0, 0xe2, 0xf0, 0xd7,
#   0xf7, 0xfe, 0x0e, 0xd2, 0x06, 0x19, 0xc8, 0x0e, 0x20, 0xd7, 0x2b, 0xd3,
#   0x29, 0x0e, 0x1d, 0x04, 0xe7, 0x01, 0x23, 0x11, 0xd4, 0x12, 0xef, 0x19,
#   0x0a, 0xef, 0xd4, 0x22, 0xe2, 0x27, 0xfa, 0xce, 0xf9, 0xf2, 0xf3, 0xd3,
#   0xff, 0xda, 0xf3, 0x00, 0xfd, 0x2a, 0xf4, 0x1b, 0x14, 0xd4, 0x16, 0x1c,
#   0xd9, 0xd2, 0x0f, 0x1d, 0x1a, 0x10, 0x11, 0xec, 0xf8, 0xff, 0xcf, 0x34,
#   0x03, 0x1c, 0x01, 0x14, 0xe9, 0xfd, 0xe6, 0xfd, 0x0d, 0xed, 0x0c, 0xd1,
#   0x25, 0xf4, 0xf6, 0xf6, 0xdb, 0xf3, 0x17, 0x11, 0x0e, 0x13, 0x3f, 0xfb,
#   0xf5, 0xd0, 0xdf, 0x13, 0xdc, 0xea, 0x21, 0x08, 0x0d, 0x10, 0xd9, 0xe6,
#   0x10, 0xeb, 0xf7, 0xed, 0xeb, 0x00, 0x08, 0x17, 0xe3, 0xe6, 0x24, 0xfa,
#   0x14, 0xf2, 0xea, 0xc4, 0xdf, 0x22, 0x10, 0xdf, 0x17, 0x1e, 0x0a, 0xfa,
#   0xc8, 0xe1, 0xd4, 0xf5, 0xf0, 0xf4, 0xe4, 0x0e, 0xf7, 0x23, 0x05, 0xfe,
#   0xfa, 0x07, 0xec, 0x02, 0xfd, 0x13, 0xd1, 0xfd, 0x00, 0xc2, 0x08, 0x33,
#   0x0d, 0x0e, 0x19, 0x09, 0xe5, 0xf4, 0xf9, 0xfe, 0xbf, 0x1a, 0x18, 0x0e,
#   0x21, 0x05, 0xc2, 0xfa, 0x0f, 0xc6, 0x0c, 0x14, 0xd7, 0xc4, 0x14, 0xd4,
#   0x0f, 0xef, 0x2d, 0xf6, 0xf8, 0x50, 0xe4, 0xf0, 0xe3, 0x4c, 0xf2, 0xea,
#   0xeb, 0xf2, 0x14, 0xff, 0xcf, 0xf1, 0x22, 0x09, 0x0a, 0x21, 0xe3, 0xdc,
#   0x10, 0xf1, 0x2c, 0x02, 0x1d, 0xe7, 0x05, 0x21, 0xec, 0xcf, 0xf9, 0x09,
#   0x0e, 0xf6, 0xed, 0xbf, 0x51, 0xd5, 0x0d, 0xe7, 0x08, 0xdd, 0x1c, 0x07,
#   0xc8, 0xe6, 0xaf, 0xe1, 0xf1, 0xf9, 0xeb, 0xfe, 0xef, 0x0e, 0xdd, 0x0c,
#   0x04, 0xf9, 0x27, 0xc7, 0x16, 0xfc, 0xfc, 0xff, 0x12, 0xff, 0xeb, 0x05,
#   0xe2, 0x0f, 0x16, 0xed, 0x12, 0x0a, 0xd8, 0xc8, 0x06, 0x12, 0xf5, 0xe7,
#   0xce, 0x05, 0x1a, 0xe4, 0xde, 0x0e, 0xf3, 0x06, 0xf9, 0xe4, 0xf6, 0xe4,
#   0xf1, 0xdb, 0xe1, 0xf1, 0x00, 0x1c, 0x3a, 0x0c, 0xfe, 0xc1, 0x0a, 0x0c,
#   0x15, 0xf0, 0xd8, 0x07, 0xdd, 0xf2, 0xec, 0x0f, 0x24, 0xec, 0x03, 0x0b,
#   0xf7, 0x34, 0x05, 0xed, 0xf7, 0x22, 0xe5, 0xf2, 0x16, 0x0c, 0x19, 0xf7,
#   0xe6, 0x0c, 0xfc, 0xe0, 0x03, 0xf7, 0xe6, 0x16, 0xec, 0xdb, 0xf2, 0x24,
#   0x0a, 0xd9, 0x0f, 0x15, 0xef, 0xe1, 0x21, 0x20, 0x02, 0x38, 0x2a, 0xf4,
#   0x36, 0x28, 0x14, 0x0d, 0x02, 0x24, 0xe2, 0xfc, 0xf8, 0xdf, 0xda, 0xc0,
#   0xe6, 0x00, 0xf9, 0x00, 0xe0, 0xd8, 0x25, 0x0a, 0x05, 0x01, 0xcd, 0xdb,
#   0xfd, 0x1a, 0x14, 0xe9, 0xfb, 0x1a, 0x14, 0x0c, 0xec, 0xdf, 0x28, 0xda,
#   0xd5, 0x07, 0x05, 0xff, 0xf9, 0xfe, 0xfb, 0x01, 0x17, 0x0b, 0xee, 0xf8,
#   0xfd, 0xf1, 0xea, 0xd5, 0xd7, 0xfc, 0xd4, 0xf0, 0x07, 0xdf, 0xfc, 0xd7,
#   0xf9, 0x12, 0x09, 0xdc, 0xcc, 0xe3, 0xf5, 0xe2, 0x08, 0xda, 0x1c, 0xe6,
#   0xe1, 0x09, 0xfe, 0xf8, 0xfc, 0xd2, 0xe3, 0x00, 0x02, 0xfc, 0xd5, 0xe0,
#   0xc5, 0x02, 0x1a, 0x0e, 0x15, 0xe2, 0xd0, 0x03, 0xd9, 0xe5, 0x08, 0xe7,
#   0xd9, 0x08, 0x15, 0x2d, 0xdf, 0xd2, 0xe3, 0xfc, 0xc9, 0x10, 0xef, 0xeb,
#   0x23, 0x07, 0xf2, 0x01, 0x1c, 0x1e, 0x23, 0x14, 0xcf, 0xe7, 0xf9, 0xf6,
#   0x03, 0xf3, 0x0c, 0x1c, 0xe5, 0xfe, 0x08, 0x15, 0xcc, 0x14, 0xf8, 0xdc,
#   0xe7, 0xee, 0xee, 0x1a, 0x09, 0x0b, 0xca, 0xe6, 0xdf, 0xed, 0xdf, 0xc3,
#   0xe2, 0x2c, 0x1b, 0xef, 0xdc, 0xfe, 0x1c, 0x01, 0xb6, 0x09, 0x12, 0xd7,
#   0x0d, 0xfb, 0xe8, 0xe1, 0xed, 0x13, 0xda, 0x23, 0x05, 0x13, 0xe1, 0x26,
#   0x05, 0xcb, 0x0a, 0x0a, 0x28, 0x18, 0xfa, 0xd6, 0xfe, 0x01, 0xcd, 0x09,
#   0xd6, 0xdb, 0x1b, 0x23, 0x10, 0xe2, 0xf3, 0xc3, 0xe1, 0xfa, 0xe9, 0x29,
#   0xd2, 0xd1, 0x18, 0xc3, 0xe3, 0xe0, 0x03, 0x1b, 0xce, 0xe8, 0x1b, 0xc3,
#   0x03, 0xf1, 0x00, 0x15, 0x1e, 0xe1, 0x12, 0x29, 0x0e, 0x02, 0xea, 0x24,
#   0x2a, 0xfb, 0x19, 0x29, 0xd9, 0x21, 0xd4, 0x1c, 0x06, 0x23, 0xed, 0x05,
#   0xf7, 0xfe, 0xc0, 0x13, 0xf8, 0xfd, 0x17, 0x0c, 0xbe, 0xcc, 0xb4, 0xdc,
#   0x09, 0x06, 0xdf, 0x30, 0xe5, 0x00, 0x44, 0xe9, 0x0a, 0x0c, 0xfd, 0x09,
#   0x1d, 0xd5, 0x28, 0xed, 0x18, 0x0a, 0x07, 0x05, 0xca, 0xf2, 0x05, 0x07,
#   0x36, 0x13, 0x11, 0x0d, 0xd6, 0x02, 0x03, 0xfb, 0xf3, 0xe9, 0x0e, 0xc6,
#   0x0c, 0xf9, 0x21, 0x1a, 0xfc, 0x1f, 0xd1, 0xeb, 0x08, 0x0b, 0x04, 0x1e,
#   0x01, 0xf9, 0x04, 0x05, 0xd0, 0xee, 0xf0, 0x06, 0xdf, 0x34, 0xfe, 0x05,
#   0x24, 0x42, 0xd2, 0x02, 0x19, 0x21, 0xec, 0x12, 0x28, 0x29, 0x00, 0xf7,
#   0xee, 0xeb, 0xfb, 0x19, 0x15, 0x28, 0x08, 0xf8, 0xfd, 0x1f, 0xd8, 0xed,
#   0x37, 0xf2, 0xdb, 0xff, 0x31, 0xfc, 0x08, 0x34, 0xff, 0x12, 0xf5, 0xf7,
#   0x18, 0x07, 0xc8, 0xfe, 0xf8, 0x3e, 0xdf, 0x0a, 0x23, 0x01, 0xec, 0xf8,
#   0xea, 0xd7, 0xfd, 0x2c, 0xfd, 0xfe, 0xfa, 0x00, 0x13, 0xd5, 0xd9, 0xf2,
#   0xfc, 0x3e, 0xeb, 0x0d, 0xda, 0x24, 0x1d, 0x12, 0x14, 0xf3, 0xec, 0x1b,
#   0xf8, 0x0b, 0xe6, 0x0c, 0xe7, 0x1e, 0x00, 0xeb, 0xf7, 0xf9, 0xe0, 0xde,
#   0x17, 0xf2, 0xf3, 0x24, 0xc0, 0xf4, 0x19, 0x04, 0xed, 0x07, 0xe0, 0xdd,
#   0x24, 0xdc, 0x05, 0xed, 0xfc, 0xf0, 0x06, 0xf3, 0x15, 0xe6, 0x17, 0x01,
#   0x05, 0xfe, 0xec, 0x1c, 0x16, 0xd5, 0xe7, 0x27, 0xe7, 0xf2, 0x04, 0x22,
#   0xe6, 0x2a, 0x13, 0xf5, 0xf6, 0x48, 0x02, 0xed, 0x15, 0x13, 0xf4, 0x04,
#   0x0b, 0x05, 0xd7, 0x2e, 0xfc, 0x16, 0x04, 0xf9, 0xfc, 0x0b, 0xf4, 0x26,
#   0x24, 0xf5, 0xfe, 0xf1, 0x01, 0xf4, 0xf3, 0x0b, 0x36, 0xf2, 0xf5, 0xfd,
#   0x12, 0x01, 0x02, 0x25, 0xfd, 0x27, 0xec, 0xe0, 0xf2, 0x05, 0xc0, 0x0e,
#   0xde, 0x20, 0xfb, 0xf5, 0xe4, 0x01, 0xf0, 0xde, 0x24, 0xe8, 0xe3, 0x37,
#   0xf9, 0xef, 0x18, 0x04, 0xfd, 0xf6, 0xf2, 0xfa, 0x09, 0x18, 0xf1, 0x14,
#   0x0f, 0x2f, 0xec, 0xec, 0x1b, 0x07, 0xea, 0x05, 0x07, 0xf2, 0x02, 0xe7,
#   0x17, 0x2c, 0xf9, 0xf0, 0xfd, 0x08, 0xf9, 0xb4, 0xf6, 0xf1, 0x24, 0x40,
#   0xe8, 0xed, 0xf7, 0x0e, 0xf6, 0xeb, 0xfa, 0xe9, 0x51, 0xc8, 0x0f, 0x09,
#   0x11, 0x0d, 0x16, 0x0a, 0xf7, 0x1d, 0xf7, 0xcc, 0xed, 0xe9, 0x2b, 0xf0,
#   0xfb, 0xda, 0xcb, 0x17, 0xf0, 0x1c, 0xfc, 0xe6, 0xff, 0x07, 0xdd, 0x0b,
#   0xf5, 0x0c, 0xed, 0x03, 0x1c, 0xd8, 0x13, 0xf9, 0xee, 0xd9, 0x0d, 0xde,
#   0xf9, 0xfe, 0xfd, 0xf1, 0x09, 0x34, 0x07, 0x07, 0xc2, 0xee, 0x00, 0x1d,
#   0xdb, 0xf9, 0xcb, 0xec, 0xfa, 0x00, 0x0d, 0xf0, 0xea, 0x11, 0x31, 0xcf,
#   0xe8, 0xe5, 0xd8, 0xd5, 0x29, 0x01, 0x00, 0xfa, 0xf9, 0xe1, 0x0e, 0xf7,
#   0x0e, 0xd9, 0x31, 0x37, 0xe9, 0x2f, 0x09, 0xda, 0xfc, 0x0b, 0xfd, 0xdb,
#   0x18, 0xf4, 0x29, 0xfd, 0x1c, 0xe4, 0x15, 0x08, 0xc4, 0xd9, 0x0f, 0x06,
#   0x14, 0x01, 0xdc, 0x06, 0xdf, 0x24, 0xe7, 0x0e, 0xf4, 0xf6, 0xf6, 0xe2,
#   0x26, 0x1e, 0x20, 0xf5, 0x28, 0xeb, 0x14, 0x14, 0x06, 0xce, 0xd4, 0xd0,
#   0x23, 0xec, 0xfc, 0xf0, 0xf7, 0xf9, 0xde, 0xd6, 0xf0, 0xed, 0xe6, 0xe9,
#   0xf4, 0xea, 0xf0, 0xe8, 0x3c, 0xc5, 0xe3, 0xcc, 0x14, 0xca, 0x25, 0xe6,
#   0xdc, 0xd3, 0x1d, 0x01, 0x07, 0x10, 0x05, 0xda, 0xd0, 0xee, 0xe1, 0xd4,
#   0xdc, 0xf0, 0xdf, 0xe9, 0xe5, 0x26, 0xf5, 0xcc, 0xf3, 0xf0, 0x1a, 0xf5,
#   0xd4, 0x0a, 0xe8, 0x1e, 0xdd, 0x13, 0x29, 0xe4, 0xed, 0xf8, 0xd2, 0xf5,
#   0xde, 0xfb, 0x1c, 0xea, 0x38, 0xd0, 0x0b, 0x17, 0x0c, 0xfe, 0xe9, 0xee,
#   0xdb, 0xe6, 0xe1, 0x22, 0xdc, 0x07, 0xf9, 0x00, 0xdd, 0xea, 0xdb, 0xeb,
#   0x04, 0x09, 0xd6, 0xb4, 0xfc, 0x14, 0x27, 0x09, 0x06, 0xf1, 0xeb, 0xf7,
#   0xbb, 0x05, 0xe6, 0x37, 0xee, 0x0f, 0x0d, 0xff, 0xed, 0xf7, 0xcb, 0xe4,
#   0xdf, 0x13, 0x20, 0xb4, 0xda, 0x24, 0xdb, 0x06, 0x07, 0x00, 0xc9, 0xb9,
#   0x09, 0xe0, 0xf4, 0xfe, 0x27, 0x09, 0xdd, 0xef, 0x09, 0x0f, 0xd8, 0x00,
#   0xde, 0x0f, 0xf8, 0xe9, 0x0e, 0x1a, 0x0b, 0x0a, 0x04, 0x2c, 0xf7, 0x07,
#   0xf0, 0x03, 0x2d, 0xb9, 0xd9, 0xf6, 0xf6, 0x07, 0xca, 0xf8, 0x28, 0xdc,
#   0xef, 0xf0, 0x01, 0x0c, 0x2d, 0xed, 0xf7, 0xeb, 0xff, 0xea, 0xfa, 0x0e,
#   0xe9, 0xe7, 0xe8, 0xd1, 0xf4, 0xd0, 0x0a, 0x13, 0x00, 0xec, 0x21, 0x15,
#   0xef, 0xff, 0xe7, 0x2c, 0xeb, 0xb7, 0x08, 0xe5, 0x19, 0xde, 0x14, 0x3e,
#   0xde, 0xfb, 0x20, 0x15, 0xdc, 0x11, 0xd7, 0xcb, 0xf5, 0xf8, 0x00, 0xdb,
#   0x19, 0xea, 0x07, 0x07, 0xf1, 0xd5, 0xf0, 0xe9, 0xde, 0xfe, 0x14, 0xea,
#   0xfd, 0xde, 0x09, 0x11, 0x2d, 0xf6, 0x03, 0xd3, 0xd8, 0xcd, 0xda, 0x14,
#   0xeb, 0x15, 0xd4, 0xb4, 0xf7, 0xdb, 0xfc, 0xfd, 0xdf, 0xfc, 0xfc, 0x0f,
#   0x00, 0x2a, 0x1b, 0x15, 0xfb, 0x06, 0x00, 0xfc, 0x1e, 0xf9, 0xf2, 0x04,
#   0xe6, 0x22, 0xf1, 0x1b, 0x1e, 0x16, 0x06, 0xfc, 0xc3, 0x28, 0x14, 0xe4,
#   0x1e, 0xfb, 0x14, 0xd8, 0x09, 0xf3, 0xe3, 0xe6, 0x0a, 0xfe, 0xfc, 0xdf,
#   0x17, 0x12, 0xdf, 0xfa, 0xec, 0xbd, 0x04, 0xfe, 0xfd, 0xd1, 0x05, 0xc7,
#   0xca, 0xf2, 0xeb, 0x0c, 0xd9, 0x27, 0x10, 0x02, 0xf0, 0xff, 0x10, 0xe2,
#   0xdb, 0xf2, 0x04, 0x12, 0xe7, 0x12, 0x21, 0xfb, 0xfb, 0xf2, 0x22, 0x21,
#   0xe4, 0xdf, 0xfb, 0x02, 0x20, 0x27, 0x01, 0xce, 0xf1, 0x1d, 0x17, 0xf6,
#   0xf8, 0xf3, 0xec, 0xdb, 0x24, 0xe6, 0xdf, 0xf5, 0xfe, 0xe9, 0xee, 0x00,
#   0xe5, 0xf5, 0xf1, 0xca, 0x13, 0x0e, 0xe7, 0xf9, 0xc3, 0x01, 0xfc, 0x01,
#   0xff, 0xeb, 0x24, 0xd9, 0xc0, 0xf0, 0xe6, 0xcb, 0x14, 0x18, 0xf0, 0xfe,
#   0x16, 0xff, 0x0f, 0xfc, 0xe0, 0x09, 0x13, 0x1c, 0x0d, 0xf7, 0x05, 0xef,
#   0xf7, 0xf4, 0x20, 0xf7, 0xec, 0x16, 0x19, 0x03, 0xd7, 0xe6, 0xe4, 0x01,
#   0xe8, 0x15, 0xde, 0xcf, 0x0b, 0xd3, 0xfd, 0xe2, 0xe5, 0xe1, 0xe9, 0x0d,
#   0xf9, 0xfc, 0xc9, 0xed, 0x0c, 0xd1, 0xd9, 0xe7, 0xf3, 0xec, 0xfb, 0x1f,
#   0xd1, 0x0b, 0xfa, 0xe8, 0x26, 0xc8, 0xe8, 0x10, 0x19, 0xd4, 0xca, 0xfe,
#   0x17, 0xee, 0xe8, 0x03, 0xf7, 0x12, 0x06, 0xfc, 0xf1, 0xeb, 0xef, 0xe6,
#   0xf3, 0xda, 0xdb, 0xf9, 0x00, 0xf1, 0xd7, 0xf9, 0xeb, 0x04, 0xce, 0xf9,
#   0x0a, 0x14, 0xe3, 0xe2, 0x08, 0x00, 0xf8, 0x02, 0x17, 0xc6, 0xe2, 0xcf,
#   0x14, 0xf0, 0xda, 0xe8, 0xec, 0x0d, 0xf7, 0xe0, 0x0b, 0xf5, 0xf7, 0xc7,
#   0xca, 0xe1, 0x17, 0xec, 0xbd, 0xf5, 0xfb, 0xe6, 0x1c, 0x0e, 0xec, 0xec,
#   0xfe, 0xe9, 0xd4, 0xea, 0x16, 0xe2, 0x0b, 0x13, 0xf7, 0x1c, 0xdc, 0xf7,
#   0xf8, 0x10, 0xe2, 0xe5, 0x04, 0xe7, 0xcf, 0x13, 0x1f, 0x1d, 0x0a, 0xf3,
#   0xf9, 0x15, 0x12, 0x13, 0xe4, 0xfd, 0xe1, 0xed, 0xeb, 0xda, 0xb7, 0x08,
#   0xd6, 0xe6, 0x14, 0x1f, 0x0c, 0xed, 0x08, 0x0f, 0xd6, 0x11, 0xca, 0xf6,
#   0x0a, 0xf0, 0xee, 0xfe, 0xfe, 0xeb, 0x13, 0xf0, 0xf6, 0xeb, 0x12, 0xb9,
#   0xf2, 0x12, 0xf4, 0xfa, 0x02, 0x02, 0xd4, 0x10, 0x05, 0x1e, 0xe9, 0x0e,
#   0x21, 0x0e, 0xe8, 0xc4, 0x00, 0xf2, 0xd6, 0xfc, 0xee, 0x0e, 0xe6, 0x01,
#   0xff, 0x05, 0xe1, 0x04, 0x03, 0x09, 0xd9, 0xff, 0x23, 0xe9, 0x2d, 0xec,
#   0xd9, 0xc3, 0x2c, 0x11, 0x03, 0xeb, 0x04, 0xda, 0xfe, 0x10, 0xda, 0xff,
# ...
#   0x58, 0xbd, 0xbe, 0x3d, 0xab, 0x44, 0x20, 0x3e, 0x14, 0x24, 0x62, 0x3e,
#   0x49, 0x64, 0x42, 0x3e, 0xc1, 0x91, 0x51, 0x3e, 0x44, 0xff, 0x3b, 0x3e,
#   0x35, 0x4c, 0x8a, 0x3e, 0x48, 0x7b, 0x17, 0x3e, 0x95, 0xc1, 0x52, 0x3e,
#   0x6c, 0x36, 0x2d, 0x3e, 0x03, 0x40, 0x41, 0x3e, 0x68, 0x5b, 0xd9, 0x3d,
#   0xb7, 0x68, 0x7a, 0x3e, 0x0a, 0xb9, 0x81, 0x3e, 0xb6, 0x79, 0x2e, 0x3e,
#   0x49, 0x5e, 0x7c, 0x3e, 0x38, 0x2f, 0x21, 0x3e, 0xdc, 0xc9, 0x07, 0x3e,
#   0x14, 0x00, 0x00, 0x00, 0x4e, 0x07, 0x43, 0xbe, 0xa3, 0x35, 0x61, 0xbe,
#   0x21, 0x7d, 0x34, 0xbe, 0xed, 0xb8, 0xbb, 0xbe, 0xa7, 0x13, 0x52, 0xbe,
#   0x86, 0x94, 0x2d, 0xbe, 0xbb, 0xd4, 0x19, 0xbe, 0x7f, 0xec, 0xb2, 0xbd,
#   0x3b, 0xeb, 0x82, 0xbe, 0xfa, 0x1b, 0xd0, 0xbd, 0x00, 0xa2, 0x88, 0xbe,
#   0xa8, 0xec, 0x0f, 0xbe, 0x6c, 0xaa, 0x4f, 0xbe, 0x49, 0xfb, 0x22, 0xbe,
#   0x4f, 0x35, 0x25, 0xbe, 0xe6, 0xc3, 0x89, 0xbe, 0xf7, 0x27, 0x1e, 0xbe,
#   0x4c, 0xb5, 0x96, 0xbe, 0xe3, 0x5a, 0x45, 0xbe, 0x56, 0x50, 0x79, 0xbe,
#   0x28, 0x00, 0x00, 0x00, 0x73, 0x69, 0x6d, 0x70, 0x6c, 0x65, 0x5f, 0x63,
#   0x6e, 0x6e, 0x2f, 0x64, 0x65, 0x70, 0x74, 0x68, 0x77, 0x69, 0x73, 0x65,
#   0x5f, 0x63, 0x6f, 0x6e, 0x76, 0x32, 0x64, 0x5f, 0x31, 0x31, 0x2f, 0x64,
#   0x65, 0x70, 0x74, 0x68, 0x77, 0x69, 0x73, 0x65, 0x00, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00,
#   0x03, 0x00, 0x00, 0x00, 0x14, 0x00, 0x00, 0x00, 0x6a, 0xf9, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x09, 0xe4, 0x01, 0x00, 0x00, 0x0b, 0x00, 0x00, 0x00,
#   0xbc, 0x01, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0xc4, 0xf7, 0xff, 0xff,
#   0x5c, 0x01, 0x00, 0x00, 0x04, 0x01, 0x00, 0x00, 0xac, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x14, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x14, 0x00, 0x00, 0x00, 0x32, 0x37, 0xb2, 0x3a, 0xe2, 0xbf, 0x9f, 0x3a,
#   0x2b, 0xf5, 0x9a, 0x3a, 0x4e, 0xc4, 0x0c, 0x3b, 0xbd, 0x5c, 0x07, 0x3b,
#   0x01, 0xbe, 0x10, 0x3b, 0x26, 0xf3, 0x00, 0x3b, 0x96, 0x44, 0x01, 0x3b,
#   0x3c, 0xcc, 0x38, 0x3b, 0x48, 0x5d, 0xe6, 0x3a, 0xd6, 0x9b, 0x86, 0x3a,
#   0xba, 0x0f, 0xf0, 0x3a, 0xbf, 0x4e, 0xc0, 0x3a, 0x80, 0x06, 0x4e, 0x3a,
#   0x74, 0x38, 0x6b, 0x3a, 0xd8, 0xed, 0x2e, 0x3b, 0x3d, 0xbf, 0xaa, 0x3a,
#   0x96, 0x54, 0xfe, 0x3a, 0xe0, 0xe9, 0xcd, 0x3a, 0xe6, 0x09, 0xf8, 0x3a,
#   0x14, 0x00, 0x00, 0x00, 0xc4, 0xd2, 0x30, 0x3e, 0x62, 0x80, 0x1e, 0x3e,
#   0x41, 0xbf, 0x19, 0x3e, 0xfa, 0x22, 0x35, 0x3e, 0x04, 0x4e, 0x86, 0x3e,
#   0x85, 0x9c, 0x8f, 0x3e, 0x7d, 0xe8, 0x0a, 0x3e, 0x0d, 0x42, 0x80, 0x3e,
#   0xa4, 0x5a, 0xb7, 0x3e, 0x8d, 0x90, 0x64, 0x3e, 0x9e, 0x8e, 0x05, 0x3e,
#   0x9b, 0x2f, 0x6e, 0x3e, 0x22, 0xce, 0x3e, 0x3e, 0x73, 0x6a, 0xcc, 0x3d,
#   0x03, 0x62, 0xe9, 0x3d, 0xfc, 0x8f, 0xad, 0x3e, 0xbf, 0x69, 0x29, 0x3e,
#   0xd3, 0x88, 0x61, 0x3e, 0x0c, 0x4e, 0x4c, 0x3e, 0xd2, 0x19, 0x76, 0x3e,
#   0x14, 0x00, 0x00, 0x00, 0x01, 0xf1, 0x7b, 0xbd, 0xa3, 0xc9, 0xbb, 0xbd,
#   0xb4, 0x6a, 0x18, 0xbe, 0xc5, 0xaa, 0x8b, 0xbe, 0x8f, 0x32, 0x67, 0xbe,
#   0x9d, 0xdc, 0x16, 0xbe, 0x7f, 0xe2, 0x7f, 0xbe, 0x47, 0x46, 0x32, 0xbe,
#   0x0b, 0x79, 0x14, 0xbe, 0xa9, 0x67, 0x2d, 0xbe, 0x60, 0xe2, 0x80, 0xbd,
#   0x75, 0xbc, 0xb2, 0xbd, 0x4a, 0xc0, 0xfc, 0xbd, 0x1c, 0x37, 0x84, 0xbd,
#   0xcb, 0x87, 0xe1, 0xbd, 0x23, 0x2d, 0x23, 0xbe, 0xbe, 0x0c, 0x12, 0xbe,
#   0xed, 0x57, 0x7c, 0xbe, 0x9a, 0x46, 0xe5, 0xbd, 0x96, 0xe3, 0x30, 0xbe,
#   0x1b, 0x00, 0x00, 0x00, 0x73, 0x69, 0x6d, 0x70, 0x6c, 0x65, 0x5f, 0x63,
#   0x6e, 0x6e, 0x2f, 0x63, 0x6f, 0x6e, 0x76, 0x32, 0x64, 0x5f, 0x32, 0x32,
#   0x2f, 0x43, 0x6f, 0x6e, 0x76, 0x32, 0x44, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x14, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x6a, 0xfb, 0xff, 0xff, 0x00, 0x00, 0x00, 0x09,
#   0x6c, 0x00, 0x00, 0x00, 0x0a, 0x00, 0x00, 0x00, 0x44, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0xc4, 0xf9, 0xff, 0xff, 0x30, 0x00, 0x00, 0x00,
#   0x24, 0x00, 0x00, 0x00, 0x18, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0xc4, 0x87, 0x9c, 0x3b,
#   0x01, 0x00, 0x00, 0x00, 0xe5, 0xb1, 0x82, 0x3e, 0x01, 0x00, 0x00, 0x00,
#   0xb4, 0x4e, 0x1b, 0xbf, 0x1a, 0x00, 0x00, 0x00, 0x73, 0x69, 0x6d, 0x70,
#   0x6c, 0x65, 0x5f, 0x63, 0x6e, 0x6e, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65,
#   0x5f, 0x33, 0x35, 0x2f, 0x4d, 0x61, 0x74, 0x4d, 0x75, 0x6c, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x80, 0x00, 0x00, 0x00,
#   0xea, 0xfb, 0xff, 0xff, 0x00, 0x00, 0x00, 0x09, 0x6c, 0x00, 0x00, 0x00,
#   0x09, 0x00, 0x00, 0x00, 0x44, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x44, 0xfa, 0xff, 0xff, 0x30, 0x00, 0x00, 0x00, 0x24, 0x00, 0x00, 0x00,
#   0x18, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0xea, 0x23, 0x7a, 0x3b, 0x01, 0x00, 0x00, 0x00,
#   0x92, 0x99, 0xe5, 0x3e, 0x01, 0x00, 0x00, 0x00, 0xa2, 0x2f, 0xf8, 0xbe,
#   0x1a, 0x00, 0x00, 0x00, 0x73, 0x69, 0x6d, 0x70, 0x6c, 0x65, 0x5f, 0x63,
#   0x6e, 0x6e, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x33, 0x34, 0x2f,
#   0x4d, 0x61, 0x74, 0x4d, 0x75, 0x6c, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x80, 0x00, 0x00, 0x00, 0x80, 0x00, 0x00, 0x00, 0x6a, 0xfc, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x09, 0x6c, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00,
#   0x44, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0xc4, 0xfa, 0xff, 0xff,
#   0x30, 0x00, 0x00, 0x00, 0x24, 0x00, 0x00, 0x00, 0x18, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x13, 0xd4, 0xa7, 0x3b, 0x01, 0x00, 0x00, 0x00, 0x4c, 0x23, 0xfa, 0x3e,
#   0x01, 0x00, 0x00, 0x00, 0x6b, 0x84, 0x26, 0xbf, 0x1a, 0x00, 0x00, 0x00,
#   0x73, 0x69, 0x6d, 0x70, 0x6c, 0x65, 0x5f, 0x63, 0x6e, 0x6e, 0x2f, 0x64,
#   0x65, 0x6e, 0x73, 0x65, 0x5f, 0x33, 0x33, 0x2f, 0x4d, 0x61, 0x74, 0x4d,
#   0x75, 0x6c, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x80, 0x00, 0x00, 0x00,
#   0x78, 0x00, 0x00, 0x00, 0xea, 0xfc, 0xff, 0xff, 0x00, 0x00, 0x00, 0x02,
#   0x38, 0x00, 0x00, 0x00, 0x07, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x08, 0x00, 0x00, 0x00, 0x04, 0x00, 0x04, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x1b, 0x00, 0x00, 0x00, 0x73, 0x69, 0x6d, 0x70, 0x6c, 0x65, 0x5f, 0x63,
#   0x6e, 0x6e, 0x2f, 0x66, 0x6c, 0x61, 0x74, 0x74, 0x65, 0x6e, 0x5f, 0x31,
#   0x31, 0x2f, 0x43, 0x6f, 0x6e, 0x73, 0x74, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x32, 0xfd, 0xff, 0xff, 0x00, 0x00, 0x00, 0x02,
#   0x68, 0x00, 0x00, 0x00, 0x06, 0x00, 0x00, 0x00, 0x28, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x24, 0xfd, 0xff, 0xff, 0x14, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x03, 0x6f, 0xe7, 0x39,
#   0x33, 0x00, 0x00, 0x00, 0x73, 0x69, 0x6d, 0x70, 0x6c, 0x65, 0x5f, 0x63,
#   0x6e, 0x6e, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x33, 0x35, 0x2f,
#   0x42, 0x69, 0x61, 0x73, 0x41, 0x64, 0x64, 0x2f, 0x52, 0x65, 0x61, 0x64,
#   0x56, 0x61, 0x72, 0x69, 0x61, 0x62, 0x6c, 0x65, 0x4f, 0x70, 0x2f, 0x72,
#   0x65, 0x73, 0x6f, 0x75, 0x72, 0x63, 0x65, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0xaa, 0xfd, 0xff, 0xff, 0x00, 0x00, 0x00, 0x02,
#   0x68, 0x00, 0x00, 0x00, 0x05, 0x00, 0x00, 0x00, 0x28, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x9c, 0xfd, 0xff, 0xff, 0x14, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x2f, 0x86, 0x49, 0x3a,
#   0x33, 0x00, 0x00, 0x00, 0x73, 0x69, 0x6d, 0x70, 0x6c, 0x65, 0x5f, 0x63,
#   0x6e, 0x6e, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x33, 0x34, 0x2f,
#   0x42, 0x69, 0x61, 0x73, 0x41, 0x64, 0x64, 0x2f, 0x52, 0x65, 0x61, 0x64,
#   0x56, 0x61, 0x72, 0x69, 0x61, 0x62, 0x6c, 0x65, 0x4f, 0x70, 0x2f, 0x72,
#   0x65, 0x73, 0x6f, 0x75, 0x72, 0x63, 0x65, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x80, 0x00, 0x00, 0x00, 0x22, 0xfe, 0xff, 0xff, 0x00, 0x00, 0x00, 0x02,
#   0x68, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x28, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x14, 0xfe, 0xff, 0xff, 0x14, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x59, 0xf5, 0x0c, 0x3b,
#   0x33, 0x00, 0x00, 0x00, 0x73, 0x69, 0x6d, 0x70, 0x6c, 0x65, 0x5f, 0x63,
#   0x6e, 0x6e, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x33, 0x33, 0x2f,
#   0x42, 0x69, 0x61, 0x73, 0x41, 0x64, 0x64, 0x2f, 0x52, 0x65, 0x61, 0x64,
#   0x56, 0x61, 0x72, 0x69, 0x61, 0x62, 0x6c, 0x65, 0x4f, 0x70, 0x2f, 0x72,
#   0x65, 0x73, 0x6f, 0x75, 0x72, 0x63, 0x65, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x80, 0x00, 0x00, 0x00, 0x9a, 0xfe, 0xff, 0xff, 0x00, 0x00, 0x00, 0x02,
#   0x54, 0x01, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00, 0x10, 0x01, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x8c, 0xfe, 0xff, 0xff, 0xb0, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x14, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x14, 0x00, 0x00, 0x00, 0xf6, 0x7e, 0x86, 0x3b,
#   0x0a, 0x8b, 0xa2, 0x3b, 0xd8, 0x49, 0x41, 0x3b, 0x9b, 0x06, 0x5c, 0x3b,
#   0xe0, 0xa6, 0x8c, 0x3b, 0xdc, 0x78, 0x5d, 0x3b, 0xb8, 0xcf, 0x90, 0x3b,
#   0xf5, 0xe6, 0x66, 0x3b, 0x9e, 0xc8, 0x7e, 0x3b, 0x6f, 0xbc, 0x5e, 0x3b,
#   0x24, 0x34, 0x92, 0x3b, 0x59, 0xf7, 0x7f, 0x3b, 0x8a, 0x8f, 0x8c, 0x3b,
#   0xa8, 0x6e, 0x84, 0x3b, 0x0f, 0x12, 0x98, 0x3b, 0xc7, 0xdc, 0x58, 0x3b,
#   0x67, 0x7f, 0xd4, 0x3b, 0x76, 0x23, 0x8b, 0x3b, 0xbe, 0xfb, 0x6d, 0x3b,
#   0xca, 0x43, 0x6e, 0x3b, 0x34, 0x00, 0x00, 0x00, 0x73, 0x69, 0x6d, 0x70,
#   0x6c, 0x65, 0x5f, 0x63, 0x6e, 0x6e, 0x2f, 0x63, 0x6f, 0x6e, 0x76, 0x32,
#   0x64, 0x5f, 0x32, 0x33, 0x2f, 0x42, 0x69, 0x61, 0x73, 0x41, 0x64, 0x64,
#   0x2f, 0x52, 0x65, 0x61, 0x64, 0x56, 0x61, 0x72, 0x69, 0x61, 0x62, 0x6c,
#   0x65, 0x4f, 0x70, 0x2f, 0x72, 0x65, 0x73, 0x6f, 0x75, 0x72, 0x63, 0x65,
#   0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x14, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x0e, 0x00, 0x18, 0x00, 0x08, 0x00, 0x07, 0x00, 0x0c, 0x00,
#   0x10, 0x00, 0x14, 0x00, 0x0e, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x02,
#   0x5c, 0x01, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x18, 0x01, 0x00, 0x00,
#   0x10, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x08, 0x00, 0x0c, 0x00, 0x00, 0x00, 0xac, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x14, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x14, 0x00, 0x00, 0x00, 0x45, 0x0e, 0x77, 0x3b, 0xeb, 0x74, 0x5d, 0x3b,
#   0x5b, 0xd0, 0x56, 0x3b, 0x35, 0x24, 0xc3, 0x3b, 0x35, 0xa6, 0xbb, 0x3b,
#   0x05, 0xa7, 0xc8, 0x3b, 0x83, 0xc2, 0xb2, 0x3b, 0x68, 0x33, 0xb3, 0x3b,
#   0x19, 0x17, 0x00, 0x3c, 0x94, 0xac, 0x9f, 0x3b, 0xca, 0x9a, 0x3a, 0x3b,
#   0x41, 0x65, 0xa6, 0x3b, 0xaa, 0x4b, 0x85, 0x3b, 0xca, 0xcd, 0x0e, 0x3b,
#   0x44, 0x0a, 0x23, 0x3b, 0xed, 0x7f, 0xf2, 0x3b, 0xc6, 0xb3, 0x6c, 0x3b,
#   0x2f, 0x49, 0xb0, 0x3b, 0xf3, 0xb9, 0x8e, 0x3b, 0xc2, 0xec, 0xab, 0x3b,
#   0x34, 0x00, 0x00, 0x00, 0x73, 0x69, 0x6d, 0x70, 0x6c, 0x65, 0x5f, 0x63,
#   0x6e, 0x6e, 0x2f, 0x63, 0x6f, 0x6e, 0x76, 0x32, 0x64, 0x5f, 0x32, 0x32,
#   0x2f, 0x42, 0x69, 0x61, 0x73, 0x41, 0x64, 0x64, 0x2f, 0x52, 0x65, 0x61,
#   0x64, 0x56, 0x61, 0x72, 0x69, 0x61, 0x62, 0x6c, 0x65, 0x4f, 0x70, 0x2f,
#   0x72, 0x65, 0x73, 0x6f, 0x75, 0x72, 0x63, 0x65, 0x00, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x14, 0x00, 0x00, 0x00, 0x14, 0x00, 0x1c, 0x00,
#   0x08, 0x00, 0x07, 0x00, 0x0c, 0x00, 0x10, 0x00, 0x14, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x18, 0x00, 0x14, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x09,
#   0x80, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x68, 0x00, 0x00, 0x00,
#   0x28, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0xff, 0xff, 0xff, 0xff, 0x18, 0x00, 0x00, 0x00, 0x1e, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x14, 0x00, 0x04, 0x00, 0x08, 0x00,
#   0x0c, 0x00, 0x10, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x30, 0x00, 0x00, 0x00,
#   0x24, 0x00, 0x00, 0x00, 0x18, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x80, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x71, 0x71, 0x31, 0x40,
#   0x01, 0x00, 0x00, 0x00, 0x00, 0xc0, 0x30, 0x44, 0x01, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00, 0x69, 0x6e, 0x70, 0x75,
#   0x74, 0x5f, 0x31, 0x32, 0x00, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x18, 0x00, 0x00, 0x00, 0x1e, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x05, 0x00, 0x00, 0x00, 0x60, 0x00, 0x00, 0x00,
#   0x44, 0x00, 0x00, 0x00, 0x28, 0x00, 0x00, 0x00, 0x1c, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0xd6, 0xff, 0xff, 0xff, 0x00, 0x00, 0x00, 0x09,
#   0x04, 0x00, 0x00, 0x00, 0x00, 0x00, 0x06, 0x00, 0x08, 0x00, 0x07, 0x00,
#   0x06, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x16, 0xf2, 0xff, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x04, 0x03, 0x00, 0x00, 0x00, 0x00, 0x00, 0x0a, 0x00,
#   0x0e, 0x00, 0x07, 0x00, 0x00, 0x00, 0x08, 0x00, 0x0a, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x11, 0x02, 0x00, 0x00, 0x00, 0x00, 0x00, 0x0a, 0x00,
#   0x0c, 0x00, 0x07, 0x00, 0x00, 0x00, 0x08, 0x00, 0x0a, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x03, 0x03, 0x00, 0x00, 0x00
# };
# unsigned int kws_model_tflite_len = 41504;
